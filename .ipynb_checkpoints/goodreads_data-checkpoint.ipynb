# %%
# %matplotlib inline
import matplotlib as mlp
import scipy
import numpy as np
import sympy
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import scale
from scipy.stats.stats import spearmanr 
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation
from sklearn import metrics
import scipy.sparse as sps
import math
from bs4 import BeautifulSoup
import requests
import re
import os
import fileinput
# import sys
# Out:
# /usr/local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import inspect

def __LINE__():
    try:
        raise Exception
    except:
        return sys.exc_info()[2].tb_frame.f_back.f_lineno

def __FILE__():
    return inspect.currentframe().f_code.co_filename

# %%
def clean_text(text):
    """ Removes white-spaces before, after, and between characters

    :param text: the string to remove clean
    :return: a "cleaned" string with no more than one white space between
    characters
    """
    return ' '.join(text.split())

df_book = pd.DataFrame(data={'Book Name' : [],'Author' : [], 'Awards List' : [], 'Genres' : [], 'Characters' : []})

# reload(sys)
# sys.setdefaultencoding('utf-8')

#TODO :
# 1. Clean awards to trim ..more , ..less
# 2. Delimit by commas 
# 3. Make a pandas dataframe and put into it the data for the book

    
# with open('book_was_better.txt','r') as book_better:
#     for url_first in book_better:
i = 0
fin = fileinput.input(files=('book_was_better.txt', 'movie_was_better.txt'),mode='r')
for url_first in fin:

# if 1:
#         url_first  = book_better.readline()
    try:
#        if (i>700):
            book_page = requests.get(url_first)

            # Strain the items from the book page
            soup = BeautifulSoup(book_page.content,"lxml")
            print i
            #Book Name

            book_name = soup.find_all('h1',attrs={"class":'bookTitle'})
            book_name = book_name[0].text
            book_name = clean_text(book_name)
            print book_name

            #Author
            author = soup.find_all('a',attrs={"class":'authorName'})[0].text

            #Awards
            awards_string = ""
            for row in soup.find_all('div',attrs={"class":'infoBoxRowItem',"itemprop":'awards'}):
                    awards_string = row.text

            #Genres
            genre_list = []
            for row in soup.find_all('a',attrs={"class":'actionLinkLite bookPageGenreLink'}):
                    genre_list.append(row.text)

            #Characters
            character_list = []
            for row in soup.find_all('a', {'href': re.compile(r'/characters')}):
                character_list.append(row.text)

            #Other editions
            m = ""
            other_editions = soup.find_all('a', {'href': re.compile(r'/work/editions/')})[1].text
            if other_editions:
                m = re.search('.*\((.*)\)', other_editions)
            if m:
                other_editions = int(m.group(1))

            #Getting number of votes for [5 4 3 2 1] star ratings
            script_text = []
            m = ""
            for row in soup.find_all('script',attrs={'type':'text/javascript+protovis'}):
                script_text.append(str(row))
            if len(script_text) >0:
                m = re.search('.*renderRatingGraph\(\[(.*)\]\).*', script_text[0])
            if m:
                rating_values_str = m.group(1)
            rating_values_list = [ int(x) for x in rating_values_str.split(",") ]

            #Average star rating
            star = soup.find_all('span',attrs={"class":'average', "itemprop":"ratingValue"})[0].text
            print star

            #Pages
            pages = soup.find_all('span',attrs={"itemprop":"numberOfPages"})
            if len(pages) > 0:
                pages = pages[0].text
            else:
                pages = ""

            #publish_date
            publish_date = soup.find_all('nobr',attrs={"class":'greyText'})
            if len(publish_date) > 0:
                publish_date = publish_date[0].text
                m = re.search('\(.*d\s(.*)\)', publish_date)
                if m:
                    publish_date = m.group(1)
            else: publish_date = soup.find_all('nobr',attrs={"class":'greyText'})
            print publish_date

            #num_reviews
            num_reviews = soup.find_all('span',attrs={"class":"count"})[0].text
            print num_reviews
            m = re.search('(.*?)\s', num_reviews)
            if m:
                num_reviews = int(m.group(1).replace(',', ''))

            print ("\nnum_reviews = ",num_reviews)

            df = pd.DataFrame({'Book Name':book_name, 'Author':author, 'Awards List':awards_string,
                               'Genres':[genre_list], 'Characters':[character_list], 'Other editions':other_editions,
                              'Star votes':[rating_values_list], 'Stars':star, 'Num_reviews':num_reviews,
                              'publish_date':publish_date, 'Pages':pages})
            df_book = df_book.append(df,ignore_index=True)

            if (i%20 == 0):
                df_book.index += (i-19)
                df_book.to_csv('goodreads_data_new.csv', mode='a', header=(True if i<21 else False), encoding="utf-8")
                df_book = pd.DataFrame()
            i +=1

    except Exception as exception:
#                 df.to_csv('skipped.csv', mode='a', header=False, ignore_index=True, encoding="utf-8")
            f = open('goodreads_skipped', 'a')
            print type(exception).__name__
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            print(exc_type, fname, exc_tb.tb_lineno)
            f.write(url_first + " "+type(exception).__name__+" "+str(exc_tb.tb_lineno)+"\n")
            f.close()
            i +=1


df_book.index += (i-19)
df_book.to_csv('goodreads_data_new.csv', mode='a', header=(True if i<21 else False), encoding="utf-8")
df_book = pd.DataFrame()

fin.close()
df_book
# Out:
# 0
# Harry Potter and the Order of the Phoenix (Harry Potter #5)
# 4.45
# June 21st 2003
# 25,751
# ('\nnum_reviews = ', u'25,751')
# 1
# Twilight (Twilight #1)
# 3.57
# October 5th 2005
# 93,258
# ('\nnum_reviews = ', u'93,258')
# 2
# Harry Potter and the Goblet of Fire (Harry Potter #4)
# 4.51
# July 8th 2000
# 27,770
# ('\nnum_reviews = ', u'27,770')
# 3
# Harry Potter and the Prisoner of Azkaban (Harry Potter #3)
# 4.51
# July 8th 1999
# 32,160
# ('\nnum_reviews = ', u'32,160')
# 4
# The Da Vinci Code (Robert Langdon #2)
# 3.77
# March 18th 2003
# 40,241
# ('\nnum_reviews = ', u'40,241')
# 5
# Harry Potter and the Sorcerer's Stone (Harry Potter #1)
# 4.43
#
# 67,668
# ('\nnum_reviews = ', u'67,668')
# 6
# Harry Potter and the Chamber of Secrets (Harry Potter #2)
# 4.36
# 1998
# 29,953
# ('\nnum_reviews = ', u'29,953')
# 7
# Harry Potter and the Half-Blood Prince (Harry Potter #6)
# 4.53
# July 16th 2005
# 24,934
# ('\nnum_reviews = ', u'24,934')
# 8
# Eragon (The Inheritance Cycle #1)
# 3.84
# June 2002
# 17,413
# ('\nnum_reviews = ', u'17,413')
# 9
# Memoirs of a Geisha
# 4.07
# September 1997
# 24,630
# ('\nnum_reviews = ', u'24,630')
# 10
# The Cat in the Hat (Beginner Books B-1)
# 4.15
# March 12th 1957
# 4,009
# ('\nnum_reviews = ', u'4,009')
# 11
# Harry Potter and the Deathly Hallows (Harry Potter #7)
# 4.6
#
# 48,842
# ('\nnum_reviews = ', u'48,842')
# 12
# The Lion, the Witch, and the Wardrobe (The Chronicles of Narnia (Publication Order) #1)
# 4.18
# October 16th 1950
# 13,935
# ('\nnum_reviews = ', u'13,935')
# 13
# The Golden Compass (His Dark Materials #1)
# 3.92
# 1995
# 13,892
# ('\nnum_reviews = ', u'13,892')
# 14
# The Lightning Thief (Percy Jackson and the Olympians #1)
# 4.22
# June 28th 2005
# 43,019
# ('\nnum_reviews = ', u'43,019')
# 15
# Ella Enchanted
# 3.96
# January 1st 1997
# 8,084
# ('\nnum_reviews = ', u'8,084')
# 16
# New Moon (Twilight #2)
# 3.52
#
# 43,367
# ('\nnum_reviews = ', u'43,367')
# 17
# Pride and Prejudice
# 4.24
# 1813
# 45,880
# ('\nnum_reviews = ', u'45,880')
# 18
# To Kill a Mockingbird (To Kill a Mockingbird #1)
# 4.25
# 1960
# 68,288
# ('\nnum_reviews = ', u'68,288')
# 19
# Charlotte's Web
# 4.14
# 1952
# 12,003
# ('\nnum_reviews = ', u'12,003')
# 20
# Holes (Holes #1)
# 3.92
# August 20th 1998
# 14,802
# ('\nnum_reviews = ', u'14,802')
# 21
# The Hunger Games (The Hunger Games #1)
# 4.35
#
# 152,311
# ('\nnum_reviews = ', u'152,311')
# 22
# The Other Boleyn Girl (The Plantagenet and Tudor Novels #9)
# 4.04
# 2001
# 15,542
# ('\nnum_reviews = ', u'15,542')
# 23
# Angels & Demons (Robert Langdon #1)
# 3.84
# May 1st 2000
# 24,236
# ('\nnum_reviews = ', u'24,236')
# 24
# How the Grinch Stole Christmas!
# 4.36
# October 12th 1957
# 2,001
# ('\nnum_reviews = ', u'2,001')
# 25
# Interview with the Vampire (The Vampire Chronicles #1)
# 3.97
# April 12th 1976
# 7,546
# ('\nnum_reviews = ', u'7,546')
# 26
# Eclipse (Twilight #3)
# 3.7
#
# 34,739
# ('\nnum_reviews = ', u'34,739')
# 27
# The Count of Monte Cristo
# 4.2
# 1845
# 14,918
# ('\nnum_reviews = ', u'14,918')
# 28
# The Fellowship of the Ring (The Lord of the Rings #1)
# 4.33
# July 29th 1954
# 13,997
# ('\nnum_reviews = ', u'13,997')
# 29
# Romeo and Juliet
# 3.73
# 1595
# 13,654
# ('\nnum_reviews = ', u'13,654')
# 30
# The Kite Runner
# 4.24
# May 29th 2003
# 56,770
# ('\nnum_reviews = ', u'56,770')
# 31
# Matilda
# 4.28
# 1988
# 9,930
# ('\nnum_reviews = ', u'9,930')
# 32
# Prince Caspian (The Chronicles of Narnia (Publication Order) #2)
# 3.96
# 1951
# 4,307
# ('\nnum_reviews = ', u'4,307')
# 33
# Gone with the Wind
# 4.27
# 1936
# 15,177
# ('\nnum_reviews = ', u'15,177')
# 34
# Charlie and the Chocolate Factory (Charlie Bucket #1)
# 4.1
# 1964
# 7,791
# ('\nnum_reviews = ', u'7,791')
# 35
# The Outsiders
# 4.05
# 1967
# 20,530
# ('\nnum_reviews = ', u'20,530')
# 36
# The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy #1)
# 4.2
# 1979
# 18,297
# ('\nnum_reviews = ', u'18,297')
# 37
# The Bad Beginning (A Series of Unfortunate Events #1)
# 3.87
#
# 10,612
# ('\nnum_reviews = ', u'10,612')
# 38
# It
# 4.16
# September 1986
# 9,364
# ('\nnum_reviews = ', u'9,364')
# 39
# The Notebook (The Notebook #1)
# 4.06
# 1996
# 16,657
# ('\nnum_reviews = ', u'16,657')
# 40
# Jurassic Park (Jurassic Park #1)
# 3.94
# June 10th 1991
# 7,505
# ('\nnum_reviews = ', u'7,505')
# 41
# The Devil Wears Prada (The Devil Wears Prada #1)
# 3.69
# January 1st 2003
# 7,774
# ('\nnum_reviews = ', u'7,774')
# 42
# The Return of the King (The Lord of the Rings #3)
# 4.5
# October 20th 1955
# 6,101
# ('\nnum_reviews = ', u'6,101')
# 43
# The Secret Garden
# 4.11
# 1911
# 12,033
# ('\nnum_reviews = ', u'12,033')
# 44
# Jane Eyre
# 4.09
# October 16th 1847
# 29,121
# ('\nnum_reviews = ', u'29,121')
# 45
# Little Women (Little Women #1)
# 4.03
# 1868
# 15,949
# ('\nnum_reviews = ', u'15,949')
# 46
# The Time Traveler's Wife
# 3.94
# 2003
# 42,265
# ('\nnum_reviews = ', u'42,265')
# 47
# My Sister's Keeper
# 4.05
# April 6th 2004
# 29,974
# ('\nnum_reviews = ', u'29,974')
# 48
# The Sisterhood of the Traveling Pants (Sisterhood #1)
# 3.74
#
# 6,255
# ('\nnum_reviews = ', u'6,255')
# 49
# The Firm
# 3.98
# February 1st 1991
# 3,059
# ('\nnum_reviews = ', u'3,059')
# 50
# Inkheart (Inkworld #1)
# 3.85
# 2003
# 9,950
# ('\nnum_reviews = ', u'9,950')
# 51
# The Polar Express
# 4.29
# October 28th 1985
# 2,306
# ('\nnum_reviews = ', u'2,306')
# 52
# Divine Secrets of the Ya-Ya Sisterhood (Ya Yas #1)
# 3.78
# 1996
# 3,751
# ('\nnum_reviews = ', u'3,751')
# 53
# The Shining (The Shining #1)
# 4.16
# January 28th 1977
# 13,715
# ('\nnum_reviews = ', u'13,715')
# 54
# The Queen of the Damned (The Vampire Chronicles #3)
# 3.85
# 1988
# 1,827
# ('\nnum_reviews = ', u'1,827')
# 55
# The Two Towers (The Lord of the Rings #2)
# 4.41
# November 11th 1954
# 6,400
# ('\nnum_reviews = ', u'6,400')
# 56
# Bridget Jones's Diary (Bridget Jones #1)
# 3.74
# 1996
# 7,755
# ('\nnum_reviews = ', u'7,755')
# 57
# I Am Legend and Other Stories
# 3.98
# 1954
# 4,292
# ('\nnum_reviews = ', u'4,292')
# 58
# 1984
# 4.13
# June 8th 1949
# 39,407
# ('\nnum_reviews = ', u'39,407')
# 59
# P.S. I Love You
# 4.0
# September 1st 2003
# 6,806
# ('\nnum_reviews = ', u'6,806')
# 60
# White Oleander
# 3.92
# 1999
# 5,649
# ('\nnum_reviews = ', u'5,649')
# 61
# Where the Heart Is
# 3.99
# January 1st 1995
# 3,009
# ('\nnum_reviews = ', u'3,009')
# 62
# The Stand
# 4.33
# 1978
# 12,811
# ('\nnum_reviews = ', u'12,811')
# 63
# The Princess Bride
# 4.25
# 1973
# 14,544
# ('\nnum_reviews = ', u'14,544')
# 64
# Stardust
# 4.06
# 1999
# 12,639
# ('\nnum_reviews = ', u'12,639')
# 65
# Girl With a Pearl Earring
# 3.84
# 1999
# 7,614
# ('\nnum_reviews = ', u'7,614')
# 66
# A Walk to Remember
# 4.15
# 1999
# 10,611
# ('\nnum_reviews = ', u'10,611')
# 67
# The Mists of Avalon (Avalon #1)
# 4.11
# December 21st 1982
# 5,328
# ('\nnum_reviews = ', u'5,328')
# 68
# The Lovely Bones
# 3.76
# 2002
# 35,650
# ('\nnum_reviews = ', u'35,650')
# 69
# Pet Sematary
# 3.89
# November 14th 1983
# 4,874
# ('\nnum_reviews = ', u'4,874')
# 70
# Running with Scissors
# 3.69
# 2002
# 11,352
# ('\nnum_reviews = ', u'11,352')
# 71
# Sense and Sensibility
# 4.05
# 1811
# 10,642
# ('\nnum_reviews = ', u'10,642')
# 72
# Perfume: The Story of a Murderer
# 3.99
# November 1985
# 9,235
# ('\nnum_reviews = ', u'9,235')
# 73
# Stuart Little
# 3.88
# 1945
# 1,832
# ('\nnum_reviews = ', u'1,832')
# 74
# The Clan of the Cave Bear (Earth's Children #1)
# 4.01
# May 4th 1980
# 4,860
# ('\nnum_reviews = ', u'4,860')
# 75
# Misery
# 4.09
# 1987
# 5,681
# ('\nnum_reviews = ', u'5,681')
# 76
# Les Misérables
# 4.13
# 1862
# 12,721
# ('\nnum_reviews = ', u'12,721')
# 77
# Breaking Dawn (Twilight #4)
# 3.7
#
# 44,023
# ('\nnum_reviews = ', u'44,023')
# 78
# The Hobbit (Middle-Earth Universe)
# 4.24
# September 21st 1937
# 35,637
# ('\nnum_reviews = ', u'35,637')
# 79
# The Joy Luck Club
# 3.89
# 1989
# 6,256
# ('\nnum_reviews = ', u'6,256')
# 80
# Blood and Chocolate
# 3.77
# August 11th 1997
# 2,006
# ('\nnum_reviews = ', u'2,006')
# 81
# Great Expectations
# 3.74
# 1860
# 11,536
# ('\nnum_reviews = ', u'11,536')
# 82
# Where the Wild Things Are
# 4.22
# 1963
# 8,501
# ('\nnum_reviews = ', u'8,501')
# 83
# Dracula (Dracula of Stoker Family #1)
# 3.97
# May 26th 1897
# 16,190
# ('\nnum_reviews = ', u'16,190')
# 84
# Dune (Dune #1)
# 4.18
# December 1st 1965
# 11,961
# ('\nnum_reviews = ', u'11,961')
# 85
# Timeline
# 3.82
# November 16th 1999
# 3,434
# ('\nnum_reviews = ', u'3,434')
# 86
# Bridget Jones: The Edge of Reason (Bridget Jones #2)
# 3.51
# 1999
# 2,115
# ('\nnum_reviews = ', u'2,115')
# 87
# Howl's Moving Castle (Howl's Moving Castle #1)
# 4.3
# 1986
# 8,341
# ('\nnum_reviews = ', u'8,341')
# 88
# The Nanny Diaries (Nanny #1)
# 3.39
# 2002
# 5,047
# ('\nnum_reviews = ', u'5,047')
# 89
# The Great Gatsby
# 3.88
# April 10th 1925
# 48,977
# ('\nnum_reviews = ', u'48,977')
# 90
# Lord of the Flies
# 3.63
# September 17th 1954
# 24,909
# ('\nnum_reviews = ', u'24,909')
# 91
# The Bourne Identity (Jason Bourne #1)
# 3.97
# 1980
# 3,698
# ('\nnum_reviews = ', u'3,698')
# 92
# Sphere
# 3.75
# 1987
# 2,133
# ('\nnum_reviews = ', u'2,133')
# 93
# Rebecca
# 4.2
# May 1938
# 13,538
# ('\nnum_reviews = ', u'13,538')
# 94
# Atonement
# 3.87
# 2001
# 14,235
# ('\nnum_reviews = ', u'14,235')
# 95
# The Horse Whisperer
# 3.75
# 1995
# 1,542
# ('\nnum_reviews = ', u'1,542')
# 96
# One Flew Over the Cuckoo's Nest
# 4.18
# 1962
# 7,261
# ('\nnum_reviews = ', u'7,261')
# 97
# Left Behind (Left Behind #1)
# 3.8
# November 12th 1995
# 3,103
# ('\nnum_reviews = ', u'3,103')
# 98
# Circle of Friends
# 3.98
# 1990
# 1,388
# ('\nnum_reviews = ', u'1,388')
# 99
# Cold Mountain
# 3.82
# January 1st 1997
# 4,675
# ('\nnum_reviews = ', u'4,675')
# 100
# Frankenstein
# 3.74
# 1818
# 18,250
# ('\nnum_reviews = ', u'18,250')
# 101
# The Runaway Jury
# 3.95
# 1996
# 1,606
# ('\nnum_reviews = ', u'1,606')
# 102
# Jumanji (Jumanji #1)
# 4.03
#
# 1,155
# ('\nnum_reviews = ', u'1,155')
# 103
# The Client
# 3.96
# 1993
# 1,783
# ('\nnum_reviews = ', u'1,783')
# 104
# Confessions of a Shopaholic (Shopaholic #1)
# 3.6
# 2000
# 10,810
# ('\nnum_reviews = ', u'10,810')
# 105
# Starship Troopers
# 3.99
# December 1st 1959
# 3,707
# ('\nnum_reviews = ', u'3,707')
# 106
# Congo
# 3.54
# 1980
# 1,509
# ('\nnum_reviews = ', u'1,509')
# 107
# Wuthering Heights
# 3.81
# December 1847
# 24,270
# ('\nnum_reviews = ', u'24,270')
# 108
# Of Mice and Men
# 3.83
# 1937
# 22,768
# ('\nnum_reviews = ', u'22,768')
# 109
# Marley and Me: Life and Love With the World's Worst Dog
# 4.11
# 2005
# 13,163
# ('\nnum_reviews = ', u'13,163')
# 110
# James and the Giant Peach
# 3.98
# 1961
# 4,718
# ('\nnum_reviews = ', u'4,718')
# 111
# A Clockwork Orange
# 3.97
# December 1962
# 9,134
# ('\nnum_reviews = ', u'9,134')
# 112
# Skipping Christmas
# 3.46
# November 6th 2001
# 3,309
# ('\nnum_reviews = ', u'3,309')
# 113
# The Girl with the Dragon Tattoo (Millennium #1)
# 4.1
# August 2005
# 61,217
# ('\nnum_reviews = ', u'61,217')
# 114
# The Lost World (Jurassic Park #2)
# 3.71
#
# 2,262
# ('\nnum_reviews = ', u'2,262')
# 115
# The Green Mile (The Green Mile #1-6)
# 4.41
# 1996
# 4,442
# ('\nnum_reviews = ', u'4,442')
# 116
# The Prince of Tides
# 4.21
# 1986
# 3,252
# ('\nnum_reviews = ', u'3,252')
# 117
# Watchmen
# 4.34
# 1987
# 10,350
# ('\nnum_reviews = ', u'10,350')
# 118
# Flowers in the Attic (Dollanganger #1)
# 3.78
#
# 5,722
# ('\nnum_reviews = ', u'5,722')
# 119
# The Bridges of Madison County
# 3.46
# April 1992
# 3,245
# ('\nnum_reviews = ', u'3,245')
# 120
# The Beach
# 3.9
# 1996
# 1,951
# ('\nnum_reviews = ', u'1,951')
# 121
# The Help
# 4.45
#
# 76,556
# ('\nnum_reviews = ', u'76,556')
# 122
# The Dark Is Rising (The Dark Is Rising #2)
# 4.06
# 1973
# 1,708
# ('\nnum_reviews = ', u'1,708')
# 123
# The City of Ember (Book of Ember #1)
# 3.85
#
# 8,910
# ('\nnum_reviews = ', u'8,910')
# 124
# Tuck Everlasting
# 3.85
# 1975
# 6,674
# ('\nnum_reviews = ', u'6,674')
# 125
# Firestarter
# 3.83
# September 29th 1980
# 1,686
# ('\nnum_reviews = ', u'1,686')
# 126
# Where the Red Fern Grows
# 4.03
# 1961
# 8,320
# ('\nnum_reviews = ', u'8,320')
# 127
# Fahrenheit 451
# 3.96
# October 1st 1953
# 27,562
# ('\nnum_reviews = ', u'27,562')
# 128
# Alice's Adventures in Wonderland & Through the Looking-Glass (Alice's Adventures in Wonderland #1-2)
# 4.06
# July 4th 1865
# 7,150
# ('\nnum_reviews = ', u'7,150')
# 129
# City of Bones (The Mortal Instruments #1)
# 4.12
#
# 48,836
# ('\nnum_reviews = ', u'48,836')
# 130
# Beloved (The Trilogy #1)
# 3.75
# 1987
# 7,174
# ('\nnum_reviews = ', u'7,174')
# 131
# The Secret Life of Bees
# 4.0
# November 2001
# 25,665
# ('\nnum_reviews = ', u'25,665')
# 132
# The Cider House Rules
# 4.09
# 1985
# 3,034
# ('\nnum_reviews = ', u'3,034')
# 133
# 'Salem's Lot
# 3.98
# October 17th 1975
# 5,574
# ('\nnum_reviews = ', u'5,574')
# 134
# A Little Princess
# 4.2
# 1902
# 4,692
# ('\nnum_reviews = ', u'4,692')
# 135
# The Handmaid's Tale
# 4.01
# 1985
# 22,222
# ('\nnum_reviews = ', u'22,222')
# 136
# The Neverending Story
# 4.17
# 1979
# 3,897
# ('\nnum_reviews = ', u'3,897')
# 137
# The Silence of the Lambs (Hannibal Lecter #2)
# 4.12
# 1988
# 3,519
# ('\nnum_reviews = ', u'3,519')
# 138
# Carrie
# 3.91
# April 5th 1974
# 7,444
# ('\nnum_reviews = ', u'7,444')
# 139
# Dead Until Dark (Sookie Stackhouse #1)
# 3.95
#
# 16,475
# ('\nnum_reviews = ', u'16,475')
# 140
# The Scarlet Letter
# 3.36
# March 16th 1850
# 10,809
# ('\nnum_reviews = ', u'10,809')
# 141
# Little House on the Prairie (Little House #2)
# 4.18
# 1935
# 2,990
# ('\nnum_reviews = ', u'2,990')
# 142
# Midnight in the Garden of Good and Evil: A Savannah Story
# 3.89
# January 13th 1994
# 6,216
# ('\nnum_reviews = ', u'6,216')
# 143
# Water for Elephants
# 4.06
# May 26th 2006
# 54,780
# ('\nnum_reviews = ', u'54,780')
# 144
# Dear John
# 4.0
# 2006
# 10,387
# ('\nnum_reviews = ', u'10,387')
# 145
# The Last Song
# 4.13
# September 8th 2008
# 10,765
# ('\nnum_reviews = ', u'10,765')
# 146
# The Princess Diaries (The Princess Diaries #1)
# 3.75
# 2000
# 4,021
# ('\nnum_reviews = ', u'4,021')
# 147
# The Shipping News
# 3.82
# 1992
# 3,799
# ('\nnum_reviews = ', u'3,799')
# 148
# The Three Musketeers (The D'Artagnan Romances #1)
# 4.05
# 1844
# 4,622
# ('\nnum_reviews = ', u'4,622')
# 149
# The Witches
# 4.16
# 1983
# 4,773
# ('\nnum_reviews = ', u'4,773')
# 150
# Along Came a Spider (Alex Cross #1)
# 4.07
# January 1st 1992
# 3,301
# ('\nnum_reviews = ', u'3,301')
# 151
# The War of the Worlds
# 3.79
# 1898
# 4,476
# ('\nnum_reviews = ', u'4,476')
# 152
# Watership Down (Watership Down #1)
# 4.05
# 1972
# 9,555
# ('\nnum_reviews = ', u'9,555')
# 153
# Beowulf
# 3.41
# 975
# 4,806
# ('\nnum_reviews = ', u'4,806')
# 154
# I, Robot (Robot 0.1)
# 4.16
# 1950
# 3,884
# ('\nnum_reviews = ', u'3,884')
# 155
# A Wrinkle in Time (Time Quintet #1)
# 4.04
# 1962
# 17,454
# ('\nnum_reviews = ', u'17,454')
# 156
# Christine
# 3.72
# April 29th 1983
# 1,878
# ('\nnum_reviews = ', u'1,878')
# 157
# The World According to Garp
# 4.06
# 1978
# 4,345
# ('\nnum_reviews = ', u'4,345')
# 158
# The Namesake
# 3.95
# September 2003
# 9,289
# ('\nnum_reviews = ', u'9,289')
# 159
# High Fidelity
# 3.94
# 1995
# 4,544
# ('\nnum_reviews = ', u'4,544')
# 160
# The Memory Keeper's Daughter
# 3.64
# 2005
# 17,689
# ('\nnum_reviews = ', u'17,689')
# 161
# Coraline
# 4.02
# 2002
# 12,803
# ('\nnum_reviews = ', u'12,803')
# 162
# Lolita
# 3.88
# 1955
# 16,683
# ('\nnum_reviews = ', u'16,683')
# 163
# Hamlet
# 4.0
# 1602
# 8,206
# ('\nnum_reviews = ', u'8,206')
# 164
# The Wonderful Wizard of Oz (Oz #1)
# 3.97
# May 17th 1900
# 8,079
# ('\nnum_reviews = ', u'8,079')
# 165
# Divergent (Divergent #1)
# 4.26
# April 25th 2011
# 98,945
# ('\nnum_reviews = ', u'98,945')
# 166
# Emma
# 3.98
# 1815
# 10,833
# ('\nnum_reviews = ', u'10,833')
# 167
# The Color Purple
# 4.16
# 1982
# 8,390
# ('\nnum_reviews = ', u'8,390')
# 168
# The Time Machine
# 3.86
# 1895
# 6,564
# ('\nnum_reviews = ', u'6,564')
# 169
# Catch-22 (Catch-22 #1)
# 3.97
# 1961
# 12,863
# ('\nnum_reviews = ', u'12,863')
# 170
# Message in a Bottle
# 3.94
# 1998
# 3,577
# ('\nnum_reviews = ', u'3,577')
# 171
# The Host (The Host #1)
# 3.84
#
# 39,240
# ('\nnum_reviews = ', u'39,240')
# 172
# Because of Winn-Dixie
# 3.99
# January 1st 2000
# 6,102
# ('\nnum_reviews = ', u'6,102')
# 173
# The Godfather (Mario Puzo's Mafia)
# 4.35
# 1969
# 5,306
# ('\nnum_reviews = ', u'5,306')
# 174
# The Tale of Despereaux
# 3.99
# 2003
# 7,974
# ('\nnum_reviews = ', u'7,974')
# 175
# Red Dragon (Hannibal Lecter #1)
# 4.0
# November 16th 1981
# 3,013
# ('\nnum_reviews = ', u'3,013')
# 176
# The Picture of Dorian Gray
# 4.05
# June 20th 1890
# 17,701
# ('\nnum_reviews = ', u'17,701')
# 177
# Fight Club
# 4.2
# 1996
# 10,416
# ('\nnum_reviews = ', u'10,416')
# 178
# Everything Is Illuminated
# 3.9
# April 16th 2002
# 6,771
# ('\nnum_reviews = ', u'6,771')
# 179
# The Pelican Brief
# 3.94
# March 1992
# 1,874
# ('\nnum_reviews = ', u'1,874')
# 180
# Chocolat (Chocolat #1)
# 3.94
# October 9th 1998
# 3,228
# ('\nnum_reviews = ', u'3,228')
# 181
# Angela's Ashes (Frank McCourt #1)
# 4.06
# 1996
# 9,367
# ('\nnum_reviews = ', u'9,367')
# 182
# The Crucible
# 3.54
# 1953
# 5,010
# ('\nnum_reviews = ', u'5,010')
# 183
# Cujo
# 3.62
# September 8th 1981
# 2,526
# ('\nnum_reviews = ', u'2,526')
# 184
# Winnie-the-Pooh (Winnie-the-Pooh #1)
# 4.33
# 1926
# 2,744
# ('\nnum_reviews = ', u'2,744')
# 185
# V for Vendetta (V for Vendetta #1-10)
# 4.25
# 1990
# 3,818
# ('\nnum_reviews = ', u'3,818')
# 186
# The Name of the Rose
# 4.1
# 1980
# 5,502
# ('\nnum_reviews = ', u'5,502')
# 187
# Mansfield Park
# 3.82
# May 1814
# 6,483
# ('\nnum_reviews = ', u'6,483')
# 188
# The House of the Spirits
# 4.19
# 1982
# 4,767
# ('\nnum_reviews = ', u'4,767')
# 189
# In Her Shoes
# 3.77
# September 1st 2002
# 2,453
# ('\nnum_reviews = ', u'2,453')
# 190
# Bridge to Terabithia
# 3.97
# 1977
# 8,664
# ('\nnum_reviews = ', u'8,664')
# 191
# The League of Extraordinary Gentlemen, Vol. 1 (The League of Extraordinary Gentlemen #1)
# 3.93
# September 2000
# 1,128
# ('\nnum_reviews = ', u'1,128')
# 192
# The Little Mermaid
# 4.01
# 1836
# 514
# ('\nnum_reviews = ', u'514')
# 193
# Seabiscuit: An American Legend
# 4.19
# June 30th 1999
# 3,430
# ('\nnum_reviews = ', u'3,430')
# 194
# The Sea of Monsters (Percy Jackson and the Olympians #2)
# 4.22
#
# 18,644
# ('\nnum_reviews = ', u'18,644')
# 195
# Love in the Time of Cholera
# 3.88
# 1985
# 14,412
# ('\nnum_reviews = ', u'14,412')
# 196
# Fried Green Tomatoes at the Whistle Stop Cafe
# 4.25
# 1987
# 4,059
# ('\nnum_reviews = ', u'4,059')
# 197
# Eat, Pray, Love
# 3.49
# 2006
# 48,679
# ('\nnum_reviews = ', u'48,679')
# 198
# Dreamcatcher
# 3.57
# March 20th 2001
# 1,718
# ('\nnum_reviews = ', u'1,718')
# 199
# The Virgin Suicides
# 3.82
# 1993
# 7,087
# ('\nnum_reviews = ', u'7,087')
# 200
# Choke
# 3.69
# May 2001
# 5,179
# ('\nnum_reviews = ', u'5,179')
# 201
# In Cold Blood
# 4.04
# 1965
# 10,842
# ('\nnum_reviews = ', u'10,842')
# 202
# The Power of One (The Power of One #1)
# 4.34
# 1989
# 4,405
# ('\nnum_reviews = ', u'4,405')
# 203
# Snow Falling on Cedars
# 3.78
# 1994
# 3,661
# ('\nnum_reviews = ', u'3,661')
# 204
# The Unbearable Lightness of Being
# 4.08
# November 1984
# 9,770
# ('\nnum_reviews = ', u'9,770')
# 205
# A Time to Kill (Lucien Wilbanks)
# 4.02
# 1989
# 3,978
# ('\nnum_reviews = ', u'3,978')
# 206
# I Am Number Four (Lorien Legacies #1)
# 3.94
#
# 13,521
# ('\nnum_reviews = ', u'13,521')
# 207
# Kiss the Girls (Alex Cross #2)
# 3.92
# 1995
# 2,636
# ('\nnum_reviews = ', u'2,636')
# 208
# Nights in Rodanthe
# 3.82
# January 1st 2002
# 3,902
# ('\nnum_reviews = ', u'3,902')
# 209
# Heidi (Heidi #1)
# 3.96
# 1880
# 2,477
# ('\nnum_reviews = ', u'2,477')
# 210
# American Psycho
# 3.81
# 1991
# 7,181
# ('\nnum_reviews = ', u'7,181')
# 211
# The Hours
# 3.9
# 1998
# 3,874
# ('\nnum_reviews = ', u'3,874')
# 212
# House of Sand and Fog
# 3.82
# 1999
# 3,446
# ('\nnum_reviews = ', u'3,446')
# 213
# The Bourne Supremacy (Jason Bourne #2)
# 4.09
# July 7th 1986
# 953
# ('\nnum_reviews = ', u'953')
# 214
# The Running Man
# 3.77
# May 1st 1982
# 1,713
# ('\nnum_reviews = ', u'1,713')
# 215
# The Diary of a Young Girl
# 4.09
# June 25th 1947
# 19,223
# ('\nnum_reviews = ', u'19,223')
# 216
# Horton Hears a Who! (Horton the Elephant)
# 4.16
# August 1954
# 1,054
# ('\nnum_reviews = ', u'1,054')
# 217
# A Prayer for Owen Meany
# 4.22
# March 28th 1989
# 10,673
# ('\nnum_reviews = ', u'10,673')
# 218
# The Exorcist (The Exorcist #1)
# 4.12
# 1971
# 2,563
# ('\nnum_reviews = ', u'2,563')
# 219
# The Voyage of the Dawn Treader (The Chronicles of Narnia (Publication Order) #3)
# 4.08
# 1951
# 4,195
# ('\nnum_reviews = ', u'4,195')
# 220
# The Boy in the Striped Pajamas
# 4.09
# 2006
# 17,243
# ('\nnum_reviews = ', u'17,243')
# 221
# The Hunt for Red October (Jack Ryan Universe #4)
# 3.99
# October 28th 1984
# 1,961
# ('\nnum_reviews = ', u'1,961')
# 222
# Beautiful Creatures (Caster Chronicles #1)
# 3.76
#
# 20,395
# ('\nnum_reviews = ', u'20,395')
# 223
# Hannibal (Hannibal Lecter #3)
# 3.7
# 1999
# 1,970
# ('\nnum_reviews = ', u'1,970')
# 224
# Catching Fire (The Hunger Games #2)
# 4.3
#
# 87,155
# ('\nnum_reviews = ', u'87,155')
# 225
# The Iliad
# 3.82
# -735
# 4,338
# ('\nnum_reviews = ', u'4,338')
# 226
# Battlefield Earth: A Saga of the Year 3000
# 3.47
# January 1st 1982
# 915
# ('\nnum_reviews = ', u'915')
# 227
# The English Patient
# 3.87
# 1992
# 3,083
# ('\nnum_reviews = ', u'3,083')
# 228
# A Midsummer Night's Dream
# 3.94
# 1595
# 5,205
# ('\nnum_reviews = ', u'5,205')
# 229
# Speak
# 3.99
# 1999
# 17,383
# ('\nnum_reviews = ', u'17,383')
# 230
# The Bonfire of the Vanities
# 3.8
# 1987
# 2,016
# ('\nnum_reviews = ', u'2,016')
# 231
# The Adventures of Huckleberry Finn
# 3.8
# December 10th 1884
# 11,746
# ('\nnum_reviews = ', u'11,746')
# 232
# The Grapes of Wrath
# 3.91
# April 14th 1939
# 12,180
# ('\nnum_reviews = ', u'12,180')
# 233
# Clear and Present Danger (Jack Ryan Universe #6)
# 4.06
# August 17th 1989
# 537
# ('\nnum_reviews = ', u'537')
# 234
# Macbeth
# 3.88
# 1606
# 7,081
# ('\nnum_reviews = ', u'7,081')
# 235
# Persuasion
# 4.13
# 1818
# 12,146
# ('\nnum_reviews = ', u'12,146')
# 236
# A Wizard of Earthsea (Earthsea Cycle #1)
# 3.99
# 1968
# 4,773
# ('\nnum_reviews = ', u'4,773')
# 237
# Needful Things
# 3.87
# October 1991
# 2,217
# ('\nnum_reviews = ', u'2,217')
# 238
# Nick & Norah's Infinite Playlist
# 3.73
#
# 4,160
# ('\nnum_reviews = ', u'4,160')
# 239
# Corelli's Mandolin
# 3.93
# 1994
# 2,115
# ('\nnum_reviews = ', u'2,115')
# 240
# Cloudy With a Chance of Meatballs (Cloudy with a Chance of Meatballs #1)
# 4.15
# 1978
# 1,712
# ('\nnum_reviews = ', u'1,712')
# 241
# Girl, Interrupted
# 3.89
# 1993
# 3,249
# ('\nnum_reviews = ', u'3,249')
# 242
# The Indian in the Cupboard (The Indian in the Cupboard #1)
# 3.88
# 1980
# 1,670
# ('\nnum_reviews = ', u'1,670')
# 243
# The Spiderwick Chronicles Box Set (The Spiderwick Chronicles #1-5)
# 4.02
# 2004
# 733
# ('\nnum_reviews = ', u'733')
# 244
# Jumper (Jumper #1)
# 3.89
# 1992
# 959
# ('\nnum_reviews = ', u'959')
# 245
# Mrs. Frisby and the Rats of NIMH (Rats of NIMH #1)
# 4.12
# 1971
# 2,536
# ('\nnum_reviews = ', u'2,536')
# 246
# Flowers for Algernon
# 4.04
# 1958
# 10,026
# ('\nnum_reviews = ', u'10,026')
# 247
# The Phantom of the Opera
# 3.97
# 1909
# 4,220
# ('\nnum_reviews = ', u'4,220')
# 248
# Fear and Loathing in Las Vegas
# 4.08
# 1971
# 4,763
# ('\nnum_reviews = ', u'4,763')
# 249
# The Children of Men
# 3.69
# 1992
# 2,215
# ('\nnum_reviews = ', u'2,215')
# 250
# The Second Summer of the Sisterhood (Sisterhood #2)
# 3.77
# 2003
# 2,074
# ('\nnum_reviews = ', u'2,074')
# 251
# Beastly (Kendra Chronicles #1)
# 3.85
# January 1st 2007
# 8,321
# ('\nnum_reviews = ', u'8,321')
# 252
# Pillar of Light (The Work and the Glory #1)
# 4.27
# October 1st 1994
# 870
# ('\nnum_reviews = ', u'870')
# 253
# Peter Pan (Peter Pan #3)
# 4.1
# 1911
# 6,635
# ('\nnum_reviews = ', u'6,635')
# 254
# Slaughterhouse-Five
# 4.05
# March 1969
# 17,953
# ('\nnum_reviews = ', u'17,953')
# 255
# The Road
# 3.95
# 2006
# 37,353
# ('\nnum_reviews = ', u'37,353')
# 256
# Into the Wild
# 3.93
# January 1st 1996
# 16,225
# ('\nnum_reviews = ', u'16,225')
# 257
# The Rainmaker
# 3.9
# 1995
# 1,443
# ('\nnum_reviews = ', u'1,443')
# 258
# Oliver Twist
# 3.84
# 1838
# 4,914
# ('\nnum_reviews = ', u'4,914')
# 259
# And Then There Were None
# 4.22
# November 6th 1939
# 15,003
# ('\nnum_reviews = ', u'15,003')
# 260
# The Andromeda Strain
# 3.86
# September 1st 1969
# 2,345
# ('\nnum_reviews = ', u'2,345')
# 261
# Breakfast at Tiffany's
# 3.89
# 1958
# 6,664
# ('\nnum_reviews = ', u'6,664')
# 262
# Alice in Wonderland (Alice's Adventures in Wonderland #1)
# 4.01
# 1865
# 8,631
# ('\nnum_reviews = ', u'8,631')
# 263
# Practical Magic
# 3.8
# 1995
# 2,364
# ('\nnum_reviews = ', u'2,364')
# 264
# The Thorn Birds
# 4.21
# 1977
# 4,273
# ('\nnum_reviews = ', u'4,273')
# 265
# Bringing Down the House: The Inside Story of Six M.I.T. Students Who Took Vegas for Millions
# 3.86
# 2002
# 1,697
# ('\nnum_reviews = ', u'1,697')
# 266
# The Island of Dr. Moreau
# 3.71
# 1896
# 2,492
# ('\nnum_reviews = ', u'2,492')
# 267
# Mystic River
# 4.19
# 2001
# 2,613
# ('\nnum_reviews = ', u'2,613')
# 268
# The Reader
# 3.73
# 1995
# 8,097
# ('\nnum_reviews = ', u'8,097')
# 269
# Brave New World
# 3.96
# 1932
# 18,034
# ('\nnum_reviews = ', u'18,034')
# 270
# The Bone Collector (Lincoln Rhyme #1)
# 4.17
# 1997
# 1,640
# ('\nnum_reviews = ', u'1,640')
# 271
# The Amityville Horror
# 3.81
# August 1st 1977
# 1,435
# ('\nnum_reviews = ', u'1,435')
# 272
# Crossing the Seas: A Diary of My Thoughts
# 4.49
#
# 30
# ('\nnum_reviews = ', u'30')
# 273
# Contact
# 4.09
# 1985
# 1,929
# ('\nnum_reviews = ', u'1,929')
# 274
# Fast Food Nation: The Dark Side of the All-American Meal
# 3.72
# January 17th 2001
# 4,940
# ('\nnum_reviews = ', u'4,940')
# 275
# The Thief Lord
# 3.94
# January 1st 2000
# 3,239
# ('\nnum_reviews = ', u'3,239')
# 276
# The Maze Runner (The Maze Runner #1)
# 4.03
#
# 47,052
# ('\nnum_reviews = ', u'47,052')
# 277
# The Pillars of the Earth (The Pillars of the Earth #1)
# 4.28
# October 1st 1989
# 25,428
# ('\nnum_reviews = ', u'25,428')
# 278
# Watchers
# 4.15
# 1987
# 2,547
# ('\nnum_reviews = ', u'2,547')
# 279
# The Ruins
# 3.48
# 2006
# 2,653
# ('\nnum_reviews = ', u'2,653')
# 280
# Northanger Abbey
# 3.79
# December 1817
# 7,896
# ('\nnum_reviews = ', u'7,896')
# 281
# Vampire Academy (Vampire Academy #1)
# 4.14
# August 16th 2007
# 18,889
# ('\nnum_reviews = ', u'18,889')
# 282
# Othello
# 3.87
# 1603
# 3,869
# ('\nnum_reviews = ', u'3,869')
# 283
# Journey to the Center of the Earth (Extraordinary Voyages #3)
# 3.83
# November 25th 1864
# 3,151
# ('\nnum_reviews = ', u'3,151')
# 284
# Shutter Island
# 4.06
# April 15th 2003
# 6,667
# ('\nnum_reviews = ', u'6,667')
# 285
# Dolores Claiborne
# 3.79
# November 1992
# 1,537
# ('\nnum_reviews = ', u'1,537')
# 286
# Shopgirl
# 3.42
#
# 2,413
# ('\nnum_reviews = ', u'2,413')
# 287
# The Hotel New Hampshire
# 3.88
# 1981
# 1,331
# ('\nnum_reviews = ', u'1,331')
# 288
# The Fountainhead
# 3.84
# 1943
# 9,687
# ('\nnum_reviews = ', u'9,687')
# 289
# Blindness (Blindness #1)
# 4.06
# 1995
# 10,147
# ('\nnum_reviews = ', u'10,147')
# 290
# The Bourne Ultimatum (Jason Bourne #3)
# 4.04
# 1990
# 742
# ('\nnum_reviews = ', u'742')
# 291
# Anna Karenina
# 4.01
# 1877
# 16,904
# ('\nnum_reviews = ', u'16,904')
# 292
# The Good Earth (House of Earth #1)
# 3.97
# 1931
# 7,841
# ('\nnum_reviews = ', u'7,841')
# 293
# Lonesome Dove (Lonesome Dove #1)
# 4.46
# 1985
# 5,038
# ('\nnum_reviews = ', u'5,038')
# 294
# Murder on the Orient Express (Hercule Poirot #10)
# 4.14
# 1934
# 6,761
# ('\nnum_reviews = ', u'6,761')
# 295
# The Fault in Our Stars
# 4.29
#
# 137,084
# ('\nnum_reviews = ', u'137,084')
# 296
# 2001: A Space Odyssey (Space Odyssey #1)
# 4.1
# April 28th 1968
# 3,339
# ('\nnum_reviews = ', u'3,339')
# 297
# Let the Right One In
# 4.07
# May 1st 2004
# 4,600
# ('\nnum_reviews = ', u'4,600')
# 298
# Different Seasons
# 4.33
# August 27th 1982
# 2,894
# ('\nnum_reviews = ', u'2,894')
# 299
# A Game of Thrones (A Song of Ice and Fire #1)
# 4.44
# August 6th 1996
# 44,265
# ('\nnum_reviews = ', u'44,265')
# 300
# One for the Money (Stephanie Plum #1)
# 4.03
# August 26th 1994
# 12,634
# ('\nnum_reviews = ', u'12,634')
# 301
# Hearts in Atlantis
# 3.79
# September 14th 1999
# 1,455
# ('\nnum_reviews = ', u'1,455')
# 302
# Cheaper by the Dozen (Cheaper by the Dozen #1)
# 3.99
# 1948
# 1,476
# ('\nnum_reviews = ', u'1,476')
# 303
# Relic (Pendergast #1)
# 4.0
# 1995
# 2,321
# ('\nnum_reviews = ', u'2,321')
# 304
# The Lorax
# 4.35
# January 1st 1971
# 3,013
# ('\nnum_reviews = ', u'3,013')
# 305
# The French Lieutenant's Woman
# 3.85
# June 1969
# 1,139
# ('\nnum_reviews = ', u'1,139')
# 306
# Forrest Gump (Forrest Gump #1)
# 4.05
# 1986
# 1,478
# ('\nnum_reviews = ', u'1,478')
# 307
# Never Let Me Go
# 3.79
# 2005
# 20,519
# ('\nnum_reviews = ', u'20,519')
# 308
# The Book Thief
# 4.35
# 2005
# 89,007
# ('\nnum_reviews = ', u'89,007')
# 309
# Alive: The Story of the Andes Survivors
# 4.07
# 1974
# 858
# ('\nnum_reviews = ', u'858')
# 310
# The Sum of All Fears (Jack Ryan Universe #7)
# 3.98
# August 14th 1991
# 516
# ('\nnum_reviews = ', u'516')
# 311
# The Borrowers (The Borrowers #1)
# 4.02
# 1952
# 1,313
# ('\nnum_reviews = ', u'1,313')
# 312
# A Christmas Carol
# 4.01
# 1843
# 10,226
# ('\nnum_reviews = ', u'10,226')
# 313
# Love Story (Love Story #1)
# 3.6
# February 14th 1970
# 2,096
# ('\nnum_reviews = ', u'2,096')
# 314
# Smilla's Sense of Snow
# 3.72
# 1992
# 1,639
# ('\nnum_reviews = ', u'1,639')
# 315
# Q & A
# 3.97
#
# 2,422
# ('\nnum_reviews = ', u'2,422')
# 316
# Stormbreaker (Alex Rider #1)
# 3.97
# January 1st 2000
# 4,103
# ('\nnum_reviews = ', u'4,103')
# 317
# Papillon
# 4.23
# 1969
# 1,314
# ('\nnum_reviews = ', u'1,314')
# 318
# The Stepford Wives
# 3.69
# 1972
# 1,299
# ('\nnum_reviews = ', u'1,299')
# 319
# All the Pretty Horses (The Border Trilogy #1)
# 3.96
# May 11th 1992
# 4,547
# ('\nnum_reviews = ', u'4,547')
# 320
# Do Androids Dream of Electric Sheep? (Blade Runner #1)
# 4.08
# 1968
# 7,334
# ('\nnum_reviews = ', u'7,334')
# 321
# The Perks Of Being A Wallflower
# 4.21
#
# 44,700
# ('\nnum_reviews = ', u'44,700')
# 322
# Even Cowgirls Get the Blues
# 3.74
# April 1976
# 1,561
# ('\nnum_reviews = ', u'1,561')
# 323
# The Tommyknockers
# 3.46
# November 10th 1987
# 1,706
# ('\nnum_reviews = ', u'1,706')
# 324
# Cannery Row (Cannery Row #1)
# 4.01
# 1945
# 3,607
# ('\nnum_reviews = ', u'3,607')
# 325
# World War Z: An Oral History of the Zombie War
# 4.0
# 2006
# 21,730
# ('\nnum_reviews = ', u'21,730')
# 326
# The Last Unicorn (The Last Unicorn #1)
# 4.17
# 1968
# 3,088
# ('\nnum_reviews = ', u'3,088')
# 327
# The Sword in the Stone (The Once and Future King #1)
# 3.91
# 1938
# 578
# ('\nnum_reviews = ', u'578')
# 328
# About a Boy
# 3.79
# 1998
# 2,659
# ('\nnum_reviews = ', u'2,659')
# 329
# Strip Tease
# 3.82
# 1993
# 537
# ('\nnum_reviews = ', u'537')
# 330
# Denali Skies
# 3.73
# February 13th 2013
# 29
# ('\nnum_reviews = ', u'29')
# 331
# Neverwhere (London Below, The World of Neverwhere)
# 4.17
# September 16th 1996
# 14,075
# ('\nnum_reviews = ', u'14,075')
# 332
# Angus, Thongs and Full-Frontal Snogging (Confessions of Georgia Nicolson #1)
# 3.74
# January 1st 1999
# 3,680
# ('\nnum_reviews = ', u'3,680')
# 333
# Like Water for Chocolate
# 3.93
# October 1992
# 6,094
# ('\nnum_reviews = ', u'6,094')
# 334
# Catch Me If You Can: The True Story of a Real Fake
# 4.04
# 1980
# 1,596
# ('\nnum_reviews = ', u'1,596')
# 335
# The Accidental Tourist
# 3.9
# August 11th 1985
# 1,600
# ('\nnum_reviews = ', u'1,600')
# 336
# The Black Cauldron (The Chronicles of Prydain #2)
# 4.13
# August 5th 1965
# 1,082
# ('\nnum_reviews = ', u'1,082')
# 337
# Black Beauty
# 3.94
# November 24th 1877
# 3,064
# ('\nnum_reviews = ', u'3,064')
# 338
# The Chamber
# 3.75
# May 1st 1994
# 1,262
# ('\nnum_reviews = ', u'1,262')
# 339
# The Reptile Room (A Series of Unfortunate Events #2)
# 3.93
# August 30th 1999
# 3,859
# ('\nnum_reviews = ', u'3,859')
# 340
# The Black Dahlia (L.A. Quartet #1)
# 3.74
# 1987
# 1,794
# ('\nnum_reviews = ', u'1,794')
# 341
# Animal Farm
# 3.85
# August 17th 1945
# 31,549
# ('\nnum_reviews = ', u'31,549')
# 342
# The Postman
# 3.87
# 1985
# 933
# ('\nnum_reviews = ', u'933')
# 343
# 300
# 3.93
# 1998
# 663
# ('\nnum_reviews = ', u'663')
# 344
# Insurgent (Divergent #2)
# 4.09
#
# 54,899
# ('\nnum_reviews = ', u'54,899')
# 345
# Mary Poppins (Mary Poppins #1)
# 4.05
# 1934
# 2,956
# ('\nnum_reviews = ', u'2,956')
# 346
# Battle Royale
# 4.24
# 1999
# 3,752
# ('\nnum_reviews = ', u'3,752')
# 347
# A Clash of Kings (A Song of Ice and Fire #2)
# 4.4
# November 16th 1998
# 19,506
# ('\nnum_reviews = ', u'19,506')
# 348
# The Odyssey
# 3.71
# -800
# 7,612
# ('\nnum_reviews = ', u'7,612')
# 349
# The Dead Zone
# 3.89
# August 1979
# 1,965
# ('\nnum_reviews = ', u'1,965')
# 350
# Sybil: The Classic True Story of a Woman Possessed by Sixteen Personalities
# 3.99
# 1973
# 1,215
# ('\nnum_reviews = ', u'1,215')
# 351
# The First Wives Club
# 3.86
# 1992
# 239
# ('\nnum_reviews = ', u'239')
# 352
# Absolute Power
# 4.14
# October 4th 1995
# 1,226
# ('\nnum_reviews = ', u'1,226')
# 353
# Life of Pi
# 3.88
# 2001
# 41,633
# ('\nnum_reviews = ', u'41,633')
# 354
# Out of Africa
# 3.96
# 1937
# 1,233
# ('\nnum_reviews = ', u'1,233')
# 355
# Under the Tuscan Sun
# 3.71
# 1996
# 2,930
# ('\nnum_reviews = ', u'2,930')
# 356
# Waiting to Exhale (Waiting To Exhale)
# 3.93
# May 28th 1992
# 386
# ('\nnum_reviews = ', u'386')
# 357
# Mockingjay (The Hunger Games #3)
# 4.03
#
# 94,868
# ('\nnum_reviews = ', u'94,868')
# 358
# Like a Fire Burning (The Work and the Glory #2)
# 4.27
# September 1st 1991
# 242
# ('\nnum_reviews = ', u'242')
# 359
# Anne of Green Gables (Anne of Green Gables #1)
# 4.21
# 1908
# 12,206
# ('\nnum_reviews = ', u'12,206')
# 360
# Sookie Stackhouse 7-copy Boxed Set (Sookie Stackhouse #1-7)
# 4.43
#
# 357
# ('\nnum_reviews = ', u'357')
# 361
# Dances with Wolves (Dances With Wolves #1)
# 4.18
# 1988
# 362
# ('\nnum_reviews = ', u'362')
# 362
# The Giver (The Giver Quartet #1)
# 4.12
# April 26th 1993
# 51,632
# ('\nnum_reviews = ', u'51,632')
# 363
# One Day
# 3.76
# June 11th 2009
# 15,593
# ('\nnum_reviews = ', u'15,593')
# 364
# Little Men (Little Women #2)
# 3.83
# January 1st 1871
# 1,148
# ('\nnum_reviews = ', u'1,148')
# 365
# Ice Station Zebra
# 3.93
# 1963
# 181
# ('\nnum_reviews = ', u'181')
# 366
# Schindler's List
# 4.34
# October 18th 1982
# 1,484
# ('\nnum_reviews = ', u'1,484')
# 367
# Baby-Sitters Club Boxed Set #1 (The Baby-Sitters Club #1-4)
# 3.82
# 1986
# 94
# ('\nnum_reviews = ', u'94')
# 368
# The Lucky One
# 4.09
# 2008
# 9,273
# ('\nnum_reviews = ', u'9,273')
# 369
# Johnny Tremain
# 3.61
# 1943
# 1,778
# ('\nnum_reviews = ', u'1,778')
# 370
# Valley of the Dolls
# 3.69
# 1966
# 2,460
# ('\nnum_reviews = ', u'2,460')
# 371
# Gone, Baby, Gone (Kenzie & Gennaro #4)
# 4.13
# July 20th 1998
# 1,412
# ('\nnum_reviews = ', u'1,412')
# 372
# The Killer Angels (The Civil War Trilogy #2)
# 4.29
# 1974
# 3,826
# ('\nnum_reviews = ', u'3,826')
# 373
# A Tree Grows in Brooklyn
# 4.23
# 1943
# 15,321
# ('\nnum_reviews = ', u'15,321')
# 374
# Possession
# 3.88
# 1990
# 3,386
# ('\nnum_reviews = ', u'3,386')
# 375
# The Girl Who Kicked the Hornet's Nest (Millennium #3)
# 4.2
# May 2007
# 26,215
# ('\nnum_reviews = ', u'26,215')
# 376
# The Talented Mr. Ripley, Ripley Under Ground, Ripley's Game (Ripley #1-3)
# 4.07
# 1985
# 90
# ('\nnum_reviews = ', u'90')
# 377
# Sleepers
# 4.17
# 1995
# 520
# ('\nnum_reviews = ', u'520')
# 378
# The Swiss Family Robinson (Companion Library)
# 3.92
# 1812
# 1,659
# ('\nnum_reviews = ', u'1,659')
# 379
# Darkly Dreaming Dexter (Dexter #1)
# 3.89
# May 5th 2004
# 5,476
# ('\nnum_reviews = ', u'5,476')
# 380
# Shiloh (Shiloh #1)
# 3.89
# January 1st 1991
# 1,610
# ('\nnum_reviews = ', u'1,610')
# 381
# Ender's Game (The Ender Quintet #1)
# 4.29
# 1985
# 36,616
# ('\nnum_reviews = ', u'36,616')
# 382
# A Tale of Two Cities
# 3.8
# 1859
# 12,264
# ('\nnum_reviews = ', u'12,264')
# 383
# The Girl Who Played with Fire (Millennium #2)
# 4.21
# June 2006
# 30,760
# ('\nnum_reviews = ', u'30,760')
# 384
# Trainspotting (Mark Renton #2)
# 4.07
# 1993
# 1,796
# ('\nnum_reviews = ', u'1,796')
# 385
# Hogfather (Discworld #20)
# 4.21
# 1996
# 1,432
# ('\nnum_reviews = ', u'1,432')
# 386
# The Vampire's Assistant (Cirque du Freak #2)
# 4.12
# May 30th 2000
# 1,231
# ('\nnum_reviews = ', u'1,231')
# 387
# Night Watch (Дозоры #1)
# 3.97
# 1998
# 1,719
# ('\nnum_reviews = ', u'1,719')
# 388
# Tara Road
# 3.87
# 1998
# 1,687
# ('\nnum_reviews = ', u'1,687')
# 389
# Solaris
# 3.97
# 1961
# 2,006
# ('\nnum_reviews = ', u'2,006')
# 390
# The Punisher, Vol. 1: Welcome Back, Frank (The Punisher, Volume IV & V #1)
# 4.19
# 2001
# 119
# ('\nnum_reviews = ', u'119')
# 391
# No Country For Old Men
# 4.12
# 2005
# 5,921
# ('\nnum_reviews = ', u'5,921')
# 392
# We Need to Talk About Kevin
# 4.06
# 2003
# 10,734
# ('\nnum_reviews = ', u'10,734')
# 393
# Star Wars: Episode III - Revenge of the Sith (Star Wars: Novelizations #3)
# 4.09
# January 1st 2004
# 532
# ('\nnum_reviews = ', u'532')
# 394
# Sarah's Key
# 4.13
# September 2006
# 25,875
# ('\nnum_reviews = ', u'25,875')
# 395
# Tess of the D'Urbervilles
# 3.75
# 1891
# 6,312
# ('\nnum_reviews = ', u'6,312')
# 396
# Madeline (Madeline)
# 4.21
# 1939
# 1,303
# ('\nnum_reviews = ', u'1,303')
# 397
# The 39 Steps (Richard Hannay #1)
# 3.6
# August 1915
# 1,550
# ('\nnum_reviews = ', u'1,550')
# 398
# Requiem for a Dream
# 4.09
# 1978
# 852
# ('\nnum_reviews = ', u'852')
# 399
# The Haunting of Hill House
# 3.89
# 1959
# 4,573
# ('\nnum_reviews = ', u'4,573')
# 400
# The Prestige
# 3.87
# 1995
# 1,390
# ('\nnum_reviews = ', u'1,390')
# 401
# Jaws
# 3.95
# February 1974
# 1,992
# ('\nnum_reviews = ', u'1,992')
# 402
# A Ring of Endless Light (Austin Family #5)
# 4.14
# May 1st 1980
# 618
# ('\nnum_reviews = ', u'618')
# 403
# The Remains of the Day
# 4.1
# 1989
# 6,721
# ('\nnum_reviews = ', u'6,721')
# 404
# The Alchemist
# 3.8
# 1988
# 51,081
# ('\nnum_reviews = ', u'51,081')
# 405
# Empire of the Sun (Empire of the Sun #1)
# 3.98
# 1984
# 600
# ('\nnum_reviews = ', u'600')
# 406
# The Wide Window (A Series of Unfortunate Events #3)
# 3.9
# 2000
# 2,837
# ('\nnum_reviews = ', u'2,837')
# 407
# Ethan Frome
# 3.34
# 1911
# 3,902
# ('\nnum_reviews = ', u'3,902')
# 408
# A Civil Action
# 3.93
# 1995
# 671
# ('\nnum_reviews = ', u'671')
# 409
# Island of the Blue Dolphins (Island of the Blue Dolphins #1)
# 3.79
# 1960
# 6,364
# ('\nnum_reviews = ', u'6,364')
# 410
# Tales from Earthsea (Earthsea Cycle #5)
# 3.99
# 2001
# 412
# ('\nnum_reviews = ', u'412')
# 411
# It's Kind of a Funny Story
# 4.14
# 2006
# 7,755
# ('\nnum_reviews = ', u'7,755')
# 412
# The Human Stain (The American Trilogy #3)
# 3.83
# 2000
# 1,539
# ('\nnum_reviews = ', u'1,539')
# 413
# Laskar Pelangi (Tetralogi Laskar Pelangi #1)
# 4.14
# 2005
# 2,360
# ('\nnum_reviews = ', u'2,360')
# 414
# Breakfast of Champions
# 4.08
# 1973
# 4,915
# ('\nnum_reviews = ', u'4,915')
# 415
# What Dreams May Come
# 3.95
# 1977
# 755
# ('\nnum_reviews = ', u'755')
# 416
# From Hell (From Hell #1-11)
# 4.16
# 1999
# 1,153
# ('\nnum_reviews = ', u'1,153')
# 417
# The Last Temptation of Christ
# 4.13
# 1952
# 539
# ('\nnum_reviews = ', u'539')
# 418
# Push
# 3.81
# January 1st 1996
# 5,442
# ('\nnum_reviews = ', u'5,442')
# 419
# A Thousand Acres
# 3.78
# 1991
# 2,110
# ('\nnum_reviews = ', u'2,110')
# 420
# East of Eden
# 4.34
# 1952
# 13,521
# ('\nnum_reviews = ', u'13,521')
# 421
# The General's Daughter (Paul Brenner #1)
# 4.07
# November 16th 1992
# 527
# ('\nnum_reviews = ', u'527')
# 422
# The Woman in White
# 3.98
# November 26th 1859
# 5,299
# ('\nnum_reviews = ', u'5,299')
# 423
# Big Trouble
# 3.81
# September 13th 1999
# 610
# ('\nnum_reviews = ', u'610')
# 424
# Persepolis: The Story of a Childhood (Persepolis #1)
# 4.22
# 2000
# 5,993
# ('\nnum_reviews = ', u'5,993')
# 425
# Abraham Lincoln: Vampire Hunter (Abraham Lincoln: Vampire Hunter #1)
# 3.7
# February 16th 2010
# 11,713
# ('\nnum_reviews = ', u'11,713')
# 426
# Ordinary People
# 3.9
# 1976
# 748
# ('\nnum_reviews = ', u'748')
# 427
# Ayat-Ayat Cinta (Ayat-Ayat Cinta #1)
# 3.81
# 2004
# 1,377
# ('\nnum_reviews = ', u'1,377')
# 428
# The Maltese Falcon
# 3.93
# 1930
# 3,278
# ('\nnum_reviews = ', u'3,278')
# 429
# Vanity Fair
# 3.75
# 1847
# 2,440
# ('\nnum_reviews = ', u'2,440')
# 430
# Diary of a Wimpy Kid (Diary of a Wimpy Kid #1)
# 3.96
# 2004
# 12,472
# ('\nnum_reviews = ', u'12,472')
# 431
# The Complete Sherlock Holmes (Sherlock Holmes #1-9)
# 4.5
# April 1st 1927
# 2,552
# ('\nnum_reviews = ', u'2,552')
# 432
# Revolutionary Road
# 3.88
# 1961
# 5,743
# ('\nnum_reviews = ', u'5,743')
# 433
# The Witching Hour (Lives of the Mayfair Witches #1)
# 4.1
# October 1st 1990
# 2,856
# ('\nnum_reviews = ', u'2,856')
# 434
# Wonder Boys
# 3.93
# March 14th 1995
# 1,566
# ('\nnum_reviews = ', u'1,566')
# 435
# The Clique (The Clique #1)
# 3.6
# May 1st 2004
# 2,331
# ('\nnum_reviews = ', u'2,331')
# 436
# Sex and the City
# 3.35
# 1996
# 1,532
# ('\nnum_reviews = ', u'1,532')
# 437
# On the Road (Duluoz Legend)
# 3.65
# September 5th 1957
# 11,269
# ('\nnum_reviews = ', u'11,269')
# 438
# Casino Royale (James Bond (Original Series) #1)
# 3.73
# 1953
# 2,818
# ('\nnum_reviews = ', u'2,818')
# 439
# Avatar: The Last Airbender (Avatar: The Last Airbender Books)
# 4.5
#
# 84
# ('\nnum_reviews = ', u'84')
# 440
# The Funhouse
# 3.6
# January 1st 1980
# 449
# ('\nnum_reviews = ', u'449')
# 441
# Moll Flanders
# 3.49
# 1721
# 1,108
# ('\nnum_reviews = ', u'1,108')
# 442
# The Tale of the Body Thief (The Vampire Chronicles #4)
# 3.7
# October 4th 1992
# 1,102
# ('\nnum_reviews = ', u'1,102')
# 443
# The Perfect Storm: A True Story of Men Against the Sea
# 4.06
#
# 1,351
# ('\nnum_reviews = ', u'1,351')
# 444
# Sahara (Dirk Pitt #11)
# 3.95
# June 1st 1992
# 705
# ('\nnum_reviews = ', u'705')
# 445
# Mrs. Dalloway
# 3.77
# May 1925
# 5,715
# ('\nnum_reviews = ', u'5,715')
# 446
# Warm Bodies (Warm Bodies #1)
# 3.94
# October 28th 2010
# 9,697
# ('\nnum_reviews = ', u'9,697')
# 447
# Hellboy, Vol. 1: Seed of Destruction (Hellboy #1)
# 4.11
# 1994
# 559
# ('\nnum_reviews = ', u'559')
# 448
# The Pact
# 3.99
# 1998
# 8,977
# ('\nnum_reviews = ', u'8,977')
# 449
# A River Runs Through It and Other Stories
# 4.16
# 1976
# 1,066
# ('\nnum_reviews = ', u'1,066')
# 450
# Curious George (Curious George Original Adventures)
# 4.13
# 1941
# 791
# ('\nnum_reviews = ', u'791')
# 451
# The Little Prince
# 4.27
# April 6th 1943
# 21,668
# ('\nnum_reviews = ', u'21,668')
# 452
# The Martian (The Martian #1)
# 4.39
# 2011
# 57,554
# ('\nnum_reviews = ', u'57,554')
# 453
# Tai-Pan (Asian Saga: Chronological Order #2)
# 4.24
# 1966
# 661
# ('\nnum_reviews = ', u'661')
# 454
# Sophie's Choice
# 4.18
# 1979
# 1,909
# ('\nnum_reviews = ', u'1,909')
# 455
# Cloud Atlas
# 4.01
# January 2004
# 16,384
# ('\nnum_reviews = ', u'16,384')
# 456
# Eaters of the Dead
# 3.63
# March 12th 1976
# 1,134
# ('\nnum_reviews = ', u'1,134')
# 457
# Ghost World
# 3.87
# March 1998
# 1,631
# ('\nnum_reviews = ', u'1,631')
# 458
# Gone Girl
# 4.02
# May 24th 2012
# 118,474
# ('\nnum_reviews = ', u'118,474')
# 459
# The Lost Symbol (Robert Langdon #3)
# 3.65
#
# 23,510
# ('\nnum_reviews = ', u'23,510')
# 460
# The Club Dumas
# 3.81
# September 1992
# 1,457
# ('\nnum_reviews = ', u'1,457')
# 461
# Horns
# 3.91
# March 1st 2009
# 6,929
# ('\nnum_reviews = ', u'6,929')
# 462
# Norwegian Wood (ノルウェイの森 #1-2)
# 4.02
# 1987
# 11,104
# ('\nnum_reviews = ', u'11,104')
# 463
# What's Eating Gilbert Grape
# 4.09
# September 1st 1991
# 378
# ('\nnum_reviews = ', u'378')
# 464
# Thank You for Smoking
# 3.92
# 1994
# 608
# ('\nnum_reviews = ', u'608')
# 465
# A Kiss Before Dying
# 3.92
# 1953
# 542
# ('\nnum_reviews = ', u'542')
# 466
# The Wild Things
# 3.45
# 2009
# 780
# ('\nnum_reviews = ', u'780')
# 467
# Not Without My Daughter
# 4.03
# 1987
# 1,001
# ('\nnum_reviews = ', u'1,001')
# 468
# The Silver Linings Playbook
# 4.01
# 2008
# 10,712
# ('\nnum_reviews = ', u'10,712')
# 469
# The Vampire Armand (The Vampire Chronicles #6)
# 3.74
# October 10th 1998
# 724
# ('\nnum_reviews = ', u'724')
# 470
# Primal Fear (Vail/Stampler #1)
# 4.19
# 1992
# 270
# ('\nnum_reviews = ', u'270')
# 471
# Fantastic Mr. Fox
# 4.02
# 1970
# 2,530
# ('\nnum_reviews = ', u'2,530')
# 472
# The Day of the Triffids (Triffids #1)
# 3.99
# 1951
# 2,139
# ('\nnum_reviews = ', u'2,139')
# 473
# Scarlett
# 3.43
# September 1st 1991
# 2,233
# ('\nnum_reviews = ', u'2,233')
# 474
# The Jane Austen Book Club
# 3.06
# January 1st 2004
# 3,701
# ('\nnum_reviews = ', u'3,701')
# 475
# Les Liaisons dangereuses
# 4.07
# 1782
# 965
# ('\nnum_reviews = ', u'965')
# 476
# Forever in Blue: The Fourth Summer of the Sisterhood (Sisterhood #4)
# 3.8
#
# 1,660
# ('\nnum_reviews = ', u'1,660')
# 477
# Outlander (Outlander #1)
# 4.2
# June 1st 1991
# 34,398
# ('\nnum_reviews = ', u'34,398')
# 478
# Ring (Ring #1)
# 3.82
# 1991
# 658
# ('\nnum_reviews = ', u'658')
# 479
# The Heart is a Lonely Hunter
# 3.96
# June 28th 1940
# 4,488
# ('\nnum_reviews = ', u'4,488')
# 480
# Robin Hood, The Prince of Thieves (Tales of Robin Hood by Alexandre Dumas #1)
# 3.99
# 1862
# 116
# ('\nnum_reviews = ', u'116')
# 481
# The Basketball Diaries
# 3.97
# 1978
# 393
# ('\nnum_reviews = ', u'393')
# 482
# The Constant Gardener
# 3.77
# 2000
# 950
# ('\nnum_reviews = ', u'950')
# 483
# The Sheltering Sky
# 3.92
# 1949
# 1,293
# ('\nnum_reviews = ', u'1,293')
# 484
# Safe Haven
# 4.18
# 2010
# 12,479
# ('\nnum_reviews = ', u'12,479')
# 485
# Smiley's People (The Karla Trilogy #3)
# 4.23
# 1979
# 548
# ('\nnum_reviews = ', u'548')
# 486
# The Good German
# 3.7
# September 30th 2001
# 457
# ('\nnum_reviews = ', u'457')
# 487
# A Girl of the Limberlost (Limberlost #2)
# 4.13
# 1909
# 1,173
# ('\nnum_reviews = ', u'1,173')
# 488
# Summer of the Monkeys
# 3.99
# January 1st 1976
# 753
# ('\nnum_reviews = ', u'753')
# 489
# Intensity
# 4.04
# 1987
# 2,161
# ('\nnum_reviews = ', u'2,161')
# 490
# I Am Legend
# 4.06
# 1954
# 3,234
# ('\nnum_reviews = ', u'3,234')
# 491
# Lost Horizon
# 3.89
# 1933
# 999
# ('\nnum_reviews = ', u'999')
# 492
# Charly (Charly #1)
# 3.97
# May 1980
# 421
# ('\nnum_reviews = ', u'421')
# 493
# Prozac Nation
# 3.56
# 1994
# 1,470
# ('\nnum_reviews = ', u'1,470')
# 494
# The Quiet American
# 3.95
# December 1955
# 1,931
# ('\nnum_reviews = ', u'1,931')
# 495
# Exodus
# 4.33
# January 1st 1958
# 1,373
# ('\nnum_reviews = ', u'1,373')
# 496
# The Age of Innocence
# 3.93
# 1920
# 4,707
# ('\nnum_reviews = ', u'4,707')
# 497
# The Velveteen Rabbit
# 4.29
# 1922
# 2,512
# ('\nnum_reviews = ', u'2,512')
# 498
# Seven Years in Tibet
# 4.04
# 1952
# 620
# ('\nnum_reviews = ', u'620')
# 499
# The BFG
# 4.21
# 1982
# 7,100
# ('\nnum_reviews = ', u'7,100')
# 500
# The Legend of Sleepy Hollow
# 3.74
# 1820
# 1,822
# ('\nnum_reviews = ', u'1,822')
# 501
# The Rules of Attraction
# 3.7
# 1987
# 1,042
# ('\nnum_reviews = ', u'1,042')
# 502
# The Deep End of the Ocean (Cappadora Family #1)
# 3.83
# 1996
# 1,052
# ('\nnum_reviews = ', u'1,052')
# 503
# Good in Bed (Cannie Shapiro #1)
# 3.69
# 2001
# 5,369
# ('\nnum_reviews = ', u'5,369')
# 504
# The Celestine Prophecy (Celestine Prophecy #1)
# 3.59
# 1993
# 3,074
# ('\nnum_reviews = ', u'3,074')
# 505
# The Last Wish (Saga o Wiedźminie #1)
# 4.2
# 1993
# 2,297
# ('\nnum_reviews = ', u'2,297')
# 506
# For Whom the Bell Tolls
# 3.95
# October 21st 1940
# 4,287
# ('\nnum_reviews = ', u'4,287')
# 507
# Jude the Obscure
# 3.8
# 1895
# 2,158
# ('\nnum_reviews = ', u'2,158')
# 508
# A Year in Provence (Provence #1)
# 3.94
# 1989
# 2,188
# ('\nnum_reviews = ', u'2,188')
# 509
# The Witches of Eastwick (Eastwick #1)
# 3.28
# 1984
# 927
# ('\nnum_reviews = ', u'927')
# 510
# Montana Sky
# 4.07
# 1996
# 827
# ('\nnum_reviews = ', u'827')
# 511
# I Capture the Castle
# 4.0
# 1948
# 6,184
# ('\nnum_reviews = ', u'6,184')
# 512
# Just Listen
# 4.07
#
# 7,020
# ('\nnum_reviews = ', u'7,020')
# 513
# A Simple Plan
# 3.91
# 1993
# 913
# ('\nnum_reviews = ', u'913')
# 514
# Gorky Park (Arkady Renko #1)
# 4.03
# 1981
# 738
# ('\nnum_reviews = ', u'738')
# 515
# Gulliver's Travels
# 3.55
# October 28th 1726
# 3,604
# ('\nnum_reviews = ', u'3,604')
# 516
# Daddy-Long-Legs (Daddy-Long-Legs #1)
# 4.09
#
# 2,502
# ('\nnum_reviews = ', u'2,502')
# 517
# Endless Love
# 3.5
# 1979
# 379
# ('\nnum_reviews = ', u'379')
# 518
# Fifty Shades of Grey (Fifty Shades #1)
# 3.68
#
# 74,209
# ('\nnum_reviews = ', u'74,209')
# 519
# Veronika Decides to Die (On the Seventh Day #2)
# 3.69
# 1998
# 5,697
# ('\nnum_reviews = ', u'5,697')
# 520
# Something Borrowed (Darcy & Rachel #1)
# 3.82
# 2004
# 11,342
# ('\nnum_reviews = ', u'11,342')
# 521
# The Body
# 4.26
# 1982
# 651
# ('\nnum_reviews = ', u'651')
# 522
# The Invention of Hugo Cabret
# 4.23
# January 1st 2007
# 12,600
# ('\nnum_reviews = ', u'12,600')
# 523
# Youth in Revolt (Youth in Revolt #1)
# 4.02
# August 1st 1993
# 837
# ('\nnum_reviews = ', u'837')
# 524
# Candy
# 4.06
# 1997
# 281
# ('\nnum_reviews = ', u'281')
# 525
# Neuromancer (Sprawl #1)
# 3.87
# 1984
# 6,038
# ('\nnum_reviews = ', u'6,038')
# 526
# All Quiet on the Western Front (All Quiet on the Western Front/The Road Back/Three Comrades #1)
# 3.9
# January 29th 1929
# 6,264
# ('\nnum_reviews = ', u'6,264')
# 527
# Doctor No (James Bond (Original Series) #6)
# 3.76
# January 1st 1958
# 624
# ('\nnum_reviews = ', u'624')
# 528
# In the Time of the Butterflies
# 4.13
# 1994
# 2,956
# ('\nnum_reviews = ', u'2,956')
# 529
# The Murder of Roger Ackroyd (Hercule Poirot #4)
# 4.18
# June 1926
# 4,365
# ('\nnum_reviews = ', u'4,365')
# 530
# Extremely Loud and Incredibly Close
# 3.97
# 2005
# 20,457
# ('\nnum_reviews = ', u'20,457')
# 531
# The Black Stallion (The Black Stallion #1)
# 4.18
#
# 905
# ('\nnum_reviews = ', u'905')
# 532
# Pictures of Hollis Woods
# 3.99
# August 28th 2002
# 1,600
# ('\nnum_reviews = ', u'1,600')
# 533
# Moby-Dick
# 3.45
# October 18th 1851
# 10,353
# ('\nnum_reviews = ', u'10,353')
# 534
# Phantoms
# 3.92
# March 1983
# 948
# ('\nnum_reviews = ', u'948')
# 535
# Beaches
# 4.13
# 1985
# 158
# ('\nnum_reviews = ', u'158')
# 536
# Pay It Forward
# 4.14
# January 1st 1999
# 743
# ('\nnum_reviews = ', u'743')
# 537
# The Hunchback of Notre-Dame
# 3.96
# January 14th 1831
# 2,922
# ('\nnum_reviews = ', u'2,922')
# 538
# Terms of Endearment
# 4.15
# 1975
# 262
# ('\nnum_reviews = ', u'262')
# 539
# The House of Mirth
# 3.94
# June 12th 1905
# 3,260
# ('\nnum_reviews = ', u'3,260')
# 540
# Blue Smoke
# 3.96
# January 1st 2005
# 756
# ('\nnum_reviews = ', u'756')
# 541
# The Juror
# 3.98
# January 1st 1995
# 82
# ('\nnum_reviews = ', u'82')
# 542
# A Scanner Darkly
# 4.04
# 1977
# 1,994
# ('\nnum_reviews = ', u'1,994')
# 543
# The Soloist: A Lost Dream, an Unlikely Friendship, and the Redemptive Power of Music
# 3.87
# January 1st 2008
# 1,347
# ('\nnum_reviews = ', u'1,347')
# 544
# Bartleby the Scrivener
# 3.89
# November 1853
# 1,663
# ('\nnum_reviews = ', u'1,663')
# 545
# Snow Flower and the Secret Fan
# 4.05
# 2005
# 15,336
# ('\nnum_reviews = ', u'15,336')
# 546
# He's Just Not That Into You: The No-Excuses Truth to Understanding Guys
# 3.64
# 2004
# 3,145
# ('\nnum_reviews = ', u'3,145')
# 547
# White Fang
# 3.93
# May 1906
# 2,728
# ('\nnum_reviews = ', u'2,728')
# 548
# Patriot Games (Jack Ryan Universe #2)
# 4.09
# August 4th 1987
# 869
# ('\nnum_reviews = ', u'869')
# 549
# Memnoch the Devil (The Vampire Chronicles #5)
# 3.73
# 1995
# 1,317
# ('\nnum_reviews = ', u'1,317')
# 550
# A Beautiful Mind
# 4.11
# June 12th 1998
# 1,020
# ('\nnum_reviews = ', u'1,020')
# 551
# Bless the Beasts and Children
# 3.5
# 1970
# 141
# ('\nnum_reviews = ', u'141')
# 552
# Doctor Zhivago
# 4.04
# 1957
# 1,933
# ('\nnum_reviews = ', u'1,933')
# 553
# Factotum
# 3.96
# 1975
# 1,112
# ('\nnum_reviews = ', u'1,112')
# 554
# On the Beach
# 3.92
# 1957
# 1,694
# ('\nnum_reviews = ', u'1,694')
# 555
# How to Train Your Dragon (How to Train Your Dragon #1)
# 3.85
# February 1st 2003
# 2,815
# ('\nnum_reviews = ', u'2,815')
# 556
# Red Riding Hood
# 3.51
# January 1st 2011
# 1,904
# ('\nnum_reviews = ', u'1,904')
# 557
# Goldfinger (James Bond (Original Series) #7)
# 3.8
# 1959
# 636
# ('\nnum_reviews = ', u'636')
# 558
# The Merchant of Venice
# 3.78
# 1596
# 2,387
# ('\nnum_reviews = ', u'2,387')
# 559
# Blood Canticle (The Vampire Chronicles #10)
# 3.71
# 2003
# 411
# ('\nnum_reviews = ', u'411')
# 560
# The Last Picture Show (The Last Picture Show #1)
# 3.95
# 1966
# 510
# ('\nnum_reviews = ', u'510')
# 561
# A Room with a View
# 3.91
# 1908
# 3,667
# ('\nnum_reviews = ', u'3,667')
# 562
# Plain Truth
# 3.96
# 2000
# 6,077
# ('\nnum_reviews = ', u'6,077')
# 563
# A Good Year
# 3.6
# March 4th 2004
# 659
# ('\nnum_reviews = ', u'659')
# 564
# Vampire Blood Trilogy (Cirque du Freak #1-3)
# 4.21
#
# 208
# ('\nnum_reviews = ', u'208')
# 565
# The Sand Pebbles
# 4.2
# 1962
# 70
# ('\nnum_reviews = ', u'70')
# 566
# I Love You, Beth Cooper
# 3.29
# January 1st 2007
# 1,172
# ('\nnum_reviews = ', u'1,172')
# 567
# Freckles (Limberlost #1)
# 4.11
# 1904
# 521
# ('\nnum_reviews = ', u'521')
# 568
# Eugene Onegin
# 4.07
# 1833
# 800
# ('\nnum_reviews = ', u'800')
# 569
# Desperation
# 3.8
# September 24th 1996
# 1,622
# ('\nnum_reviews = ', u'1,622')
# 570
# Tell No One
# 4.11
# June 19th 2001
# 3,479
# ('\nnum_reviews = ', u'3,479')
# 571
# The Ruby in the Smoke (Sally Lockhart #1)
# 3.75
# 1985
# 1,058
# ('\nnum_reviews = ', u'1,058')
# 572
# Lasher (Lives of the Mayfair Witches #2)
# 3.83
# 1993
# 733
# ('\nnum_reviews = ', u'733')
# 573
# The Executioner's Song
# 4.07
# October 30th 1979
# 908
# ('\nnum_reviews = ', u'908')
# 574
# Point of Impact (Bob Lee Swagger #1)
# 4.26
# February 1st 1993
# 532
# ('\nnum_reviews = ', u'532')
# 575
# The Secret (The Secret #1)
# 3.61
#
# 9,133
# ('\nnum_reviews = ', u'9,133')
# 576
# Moonraker (James Bond (Original Series) #3)
# 3.69
# January 1st 1955
# 829
# ('\nnum_reviews = ', u'829')
# 577
# Brick Lane
# 3.37
# 2003
# 1,504
# ('\nnum_reviews = ', u'1,504')
# 578
# Hoot
# 3.8
# 2002
# 3,723
# ('\nnum_reviews = ', u'3,723')
# 579
# If I Stay (If I Stay #1)
# 3.96
#
# 33,639
# ('\nnum_reviews = ', u'33,639')
# 580
# Raise the Titanic! (Dirk Pitt #3)
# ...
# Chéri (Chéri #1)
# 3.66
# 1920
# 112
# ('\nnum_reviews = ', u'112')
# 2042
# Ligo Na U, Lapit Na Me
# 3.84
#
# 132
# ('\nnum_reviews = ', u'132')
# 2043
# Love Comes Softly (Love Comes Softly #1)
# 4.22
# January 1st 1979
# 968
# ('\nnum_reviews = ', u'968')
# 2044
# Mrs. Palfrey at the Claremont
# 3.97
# 1971
# 263
# ('\nnum_reviews = ', u'263')
# 2045
# Crash
# 3.58
# 1973
# 853
# ('\nnum_reviews = ', u'853')
# 2046
# Where She Went (If I Stay #2)
# 4.07
#
# 17,882
# ('\nnum_reviews = ', u'17,882')
# 2047
# Fatelessness (The Holocaust series)
# 4.03
# 1975
# 413
# ('\nnum_reviews = ', u'413')
# 2048
# Crazy in Alabama
# 3.93
# 1993
# 244
# ('\nnum_reviews = ', u'244')
# 2049
# The Earthsea Trilogy (Earthsea Cycle #1-3)
# 4.24
# January 1st 1975
# 284
# ('\nnum_reviews = ', u'284')
# 2050
# Love, Rosie
# 3.95
# November 1st 2004
# 7,764
# ('\nnum_reviews = ', u'7,764')
# 2051
# Pandora Hearts パンドラハーツ 1 (Pandora Hearts #1)
# 4.21
# January 1st 2006
# 353
# ('\nnum_reviews = ', u'353')
# 2052
# The Outsider
# 3.96
# 1996
# 150
# ('\nnum_reviews = ', u'150')
# 2053
# Pact of the Fathers
# 3.03
# 2001
# 8
# ('\nnum_reviews = ', u'8')
# 2054
# Hector and the Search for Happiness (Hector #1)
# 3.47
# 2002
# 1,292
# ('\nnum_reviews = ', u'1,292')
# 2055
# Anatomy of a Murder
# 4.0
# 1958
# 154
# ('\nnum_reviews = ', u'154')
# 2056
# Zazie in the Metro
# 3.74
# 1959
# 246
# ('\nnum_reviews = ', u'246')
# 2057
# The Hunter (Parker #1)
# 4.07
#
# 569
# ('\nnum_reviews = ', u'569')
# 2058
# Coraline
# 3.96
#
# 1,281
# ('\nnum_reviews = ', u'1,281')
# 2059
# The Invention of Hugo Cabret
# 4.23
# January 1st 2007
# 12,600
# ('\nnum_reviews = ', u'12,600')
# 2060
# The Thirty-First of June
# 3.77
# 1961
# 4
# ('\nnum_reviews = ', u'4')
# 2061
# Dance Me Outside
# 4.2
# 1977
# 33
# ('\nnum_reviews = ', u'33')
# 2062
# Alone Yet Not Alone: Their faith became their freedom
# 4.08
# 2012
# 142
# ('\nnum_reviews = ', u'142')
# 2063
# Matchstick Men: A Novel About Grifters with Issues
# 3.63
# 2002
# 72
# ('\nnum_reviews = ', u'72')
# 2064
# The Lady in the Van
# 3.7
# January 1st 1999
# 393
# ('\nnum_reviews = ', u'393')
# 2065
# It's Kind of a Funny Story
# 4.14
# 2006
# 7,755
# ('\nnum_reviews = ', u'7,755')
# 2066
# Divergent Series Complete Box Set (Divergent #1-3)
# 4.33
#
# 1,094
# ('\nnum_reviews = ', u'1,094')
# 2067
# Big Trouble
# 3.81
# September 13th 1999
# 610
# ('\nnum_reviews = ', u'610')
# 2068
# The Night Manager
# 3.78
# June 28th 1993
# 547
# ('\nnum_reviews = ', u'547')
# 2069
# Tinker Tailor Soldier Spy (The Karla Trilogy #1)
# 4.03
# 1974
# 2,789
# ('\nnum_reviews = ', u'2,789')
# 2070
# Gone Girl
# 4.02
# May 24th 2012
# 118,479
# ('\nnum_reviews = ', u'118,479')
# 2071
# Under the Skin
# 3.72
# 2000
# 1,748
# ('\nnum_reviews = ', u'1,748')
# 2072
# The Carrie Diaries (The Carrie Diaries #1)
# 3.57
# 2010
# 2,323
# ('\nnum_reviews = ', u'2,323')
# 2073
# Le Petit Prince
# 4.26
#
# 277
# ('\nnum_reviews = ', u'277')
# 2074
# Music from the motion picture The bridges of Madison County : [piano, vocal, chords].
# 4.75
#
# 0
# ('\nnum_reviews = ', u'0')
# 2075
# Bella Mafia
# 4.18
# June 14th 1990
# 49
# ('\nnum_reviews = ', u'49')
# 2076
# Sometimes a Great Notion
# 4.24
# January 1st 1964
# 1,016
# ('\nnum_reviews = ', u'1,016')
# 2077
# Aunt Julia and the Scriptwriter
# 3.9
# 1977
# 721
# ('\nnum_reviews = ', u'721')
# 2078
# Suzanne's Diary for Nicholas
# 4.15
# 2001
# 4,135
# ('\nnum_reviews = ', u'4,135')
# 2079
# My Friend Flicka (Flicka #1)
# 4.14
# 1941
# 271
# ('\nnum_reviews = ', u'271')
# 2080
# Flicka: Untamed Spirit
# 4.03
# September 1st 2006
# 5
# ('\nnum_reviews = ', u'5')
# 2081
# The Hole
# 3.38
# 1993
# 84
# ('\nnum_reviews = ', u'84')
# 2082
# The Railway Children
# 3.99
# 1906
# 865
# ('\nnum_reviews = ', u'865')
# 2083
# Un dimanche à la piscine à Kigali
# 3.92
# 2000
# 280
# ('\nnum_reviews = ', u'280')
# 2084
# The Lorax
# 4.35
# January 1st 1971
# 3,013
# ('\nnum_reviews = ', u'3,013')
# 2085
# Basil of Baker Street (Basil of Baker Street #1)
# 3.91
# 1958
# 78
# ('\nnum_reviews = ', u'78')
# 2086
# The Pianist: The Extraordinary Story of One Man's Survival in Warsaw, 1939–45
# 4.24
# 1946
# 751
# ('\nnum_reviews = ', u'751')
# 2087
# The Sea-Hawk
# 4.02
# 1915
# 119
# ('\nnum_reviews = ', u'119')
# 2088
# Sounder
# 3.96
# January 1st 1969
# 859
# ('\nnum_reviews = ', u'859')
# 2089
# Brideshead Revisited
# 3.99
# 1945
# 3,168
# ('\nnum_reviews = ', u'3,168')
# 2090
# Last Exit to Brooklyn
# 3.94
# 1964
# 901
# ('\nnum_reviews = ', u'901')
# 2091
# The Redemption of Sarah Cain
# 4.05
# July 1st 2000
# 198
# ('\nnum_reviews = ', u'198')
# 2092
# Norwegian Wood (ノルウェイの森 #1-2)
# 4.02
# 1987
# 11,104
# ('\nnum_reviews = ', u'11,104')
# 2093
# The Mist
# 3.9
# 1980
# 1,371
# ('\nnum_reviews = ', u'1,371')
# 2094
# A Simple Plan
# 3.91
# 1993
# 913
# ('\nnum_reviews = ', u'913')
# 2095
# The Nameless
# 3.28
# 1981
# 36
# ('\nnum_reviews = ', u'36')
# 2096
# The Other Boleyn Girl (The Plantagenet and Tudor Novels #9)
# 4.04
# 2001
# 15,542
# ('\nnum_reviews = ', u'15,542')
# 2097
# Jewels
# 3.92
# January 1st 1992
# 212
# ('\nnum_reviews = ', u'212')
# 2098
# The Invisible Man
# 3.61
# 1897
# 3,305
# ('\nnum_reviews = ', u'3,305')
# 2099
# The Color of Magic (Discworld #1)
# 3.96
# 1983
# 5,903
# ('\nnum_reviews = ', u'5,903')
# 2100
# Scott Pilgrim, Volume 6: Scott Pilgrim's Finest Hour (Scott Pilgrim #6)
# 4.41
#
# 1,070
# ('\nnum_reviews = ', u'1,070')
# 2101
# The Hundred-Foot Journey
# 3.53
# 2008
# 3,219
# ('\nnum_reviews = ', u'3,219')
# 2102
# Macbeth
# 3.88
# 1606
# 7,081
# ('\nnum_reviews = ', u'7,081')
# 2103
# Rocketeer: The Complete Adventures (The Rocketeer)
# 4.07
# 2009
# 104
# ('\nnum_reviews = ', u'104')
# 2104
# Pride and Prejudice and Zombies (Pride and Prejudice and Zombies #1)
# 3.28
# 2009
# 11,841
# ('\nnum_reviews = ', u'11,841')
# 2105
# 20,000 Leagues Under the Sea
# 3.97
# May 1st 1948
# 89
# ('\nnum_reviews = ', u'89')
# 2106
# Blue Is the Warmest Color
# 3.91
# April 1st 2010
# 1,686
# ('\nnum_reviews = ', u'1,686')
# 2107
# Me & Earl & the Dying Girl
# 3.58
#
# 10,539
# ('\nnum_reviews = ', u'10,539')
# 2108
# The Road
# 3.95
# 2006
# 37,357
# ('\nnum_reviews = ', u'37,357')
# 2109
# The Dark Room
# 3.69
# January 1st 2001
# 202
# ('\nnum_reviews = ', u'202')
# 2110
# The Pope of Greenwich Village
# 3.83
# 1979
# 13
# ('\nnum_reviews = ', u'13')
# 2111
# Red Harvest (The Continental Op #1)
# 4.0
# 1929
# 938
# ('\nnum_reviews = ', u'938')
# 2112
# Derailed
# 3.77
# January 1st 2003
# 199
# ('\nnum_reviews = ', u'199')
# 2113
# The Wire in the Blood (Tony Hill & Carol Jordan #2)
# 4.2
# 1997
# 375
# ('\nnum_reviews = ', u'375')
# 2114
# Strangers on a Train
# 3.84
# 1950
# 925
# ('\nnum_reviews = ', u'925')
# 2115
# Jakob the Liar
# 3.76
# 1969
# 80
# ('\nnum_reviews = ', u'80')
# 2116
# The Box Of Delights (Kay Harker #2)
# 3.95
# 1935
# 136
# ('\nnum_reviews = ', u'136')
# 2117
# Roadside Picnic
# 4.21
# 1972
# 1,289
# ('\nnum_reviews = ', u'1,289')
# 2118
# The Lady Vanishes
# 3.79
# 1936
# 70
# ('\nnum_reviews = ', u'70')
# 2119
# Moneyball: The Art of Winning an Unfair Game
# 4.23
# 2003
# 3,820
# ('\nnum_reviews = ', u'3,820')
# 2120
# Tre metri sopra il cielo (Tre metri sopra il cielo #1)
# 3.49
# 1992
# 455
# ('\nnum_reviews = ', u'455')
# 2121
# Mildred Pierce
# 3.93
# 1941
# 739
# ('\nnum_reviews = ', u'739')
# 2122
# Night Shift (Night Shift #1-20)
# 3.95
# January 1st 1978
# 1,766
# ('\nnum_reviews = ', u'1,766')
# 2123
# Scott Pilgrim Bundle (Scott Pilgrim #1-6)
# 4.53
# January 5th 2010
# 251
# ('\nnum_reviews = ', u'251')
# 2124
# The World of Henry Orient
# 4.1
# 1956
# 14
# ('\nnum_reviews = ', u'14')
# 2125
# The Positronic Man (Robot 0.6)
# 4.05
# 1992
# 127
# ('\nnum_reviews = ', u'127')
# 2126
# Something Wicked This Way Comes (Green Town #2)
# 3.95
# 1962
# 4,239
# ('\nnum_reviews = ', u'4,239')
# 2127
# The Seven Pillars of Wisdom: a triumph
# 4.01
# 1922
# 454
# ('\nnum_reviews = ', u'454')
# 2128
# Even Cowgirls Get the Blues
# 3.74
# April 1976
# 1,561
# ('\nnum_reviews = ', u'1,561')
# 2129
# Man of Steel
# 3.81
# January 1st 2013
# 74
# ('\nnum_reviews = ', u'74')
# 2130
# Parade's End (Parade's End #1-4)
# 3.92
# 1928
# 382
# ('\nnum_reviews = ', u'382')
# 2131
# Prozac Nation
# 3.56
# 1994
# 1,471
# ('\nnum_reviews = ', u'1,471')
# 2132
# Never Goodnight
# 3.6
# 2008
# 26
# ('\nnum_reviews = ', u'26')
# 2133
# Bad Behavior
# 3.9
# 1988
# 440
# ('\nnum_reviews = ', u'440')
# 2134
# Dark Places
# 3.91
#
# 27,125
# ('\nnum_reviews = ', u'27,125')
# 2135
# The War of the Roses (The War of the Roses #1)
# 3.41
# January 1st 1981
# 68
# ('\nnum_reviews = ', u'68')
# 2136
# A Morbid Taste for Bones (Chronicles of Brother Cadfael #1)
# 3.99
# 1977
# 917
# ('\nnum_reviews = ', u'917')
# 2137
# Kneller's Happy Campers
# 4.03
# 1998
# 117
# ('\nnum_reviews = ', u'117')
# 2138
# Nanny McPhee: Based on the Collected Tales of Nurse Matilda (Nurse Matilda #1-3)
# 3.83
# January 1st 2005
# 127
# ('\nnum_reviews = ', u'127')
# 2139
# Point of Impact (Bob Lee Swagger #1)
# 4.26
# February 1st 1993
# 532
# ('\nnum_reviews = ', u'532')
# 2140
# Blue Exorcist, Vol. 1 (Blue Exorcist #1)
# 4.36
# August 4th 2009
# 430
# ('\nnum_reviews = ', u'430')
# 2141
# Abzurdah
# 3.11
#
# 293
# ('\nnum_reviews = ', u'293')
# 2142
# Freakonomics: A Rogue Economist Explores the Hidden Side of Everything (Freakonomics #1)
# 3.93
# April 12th 2005
# 13,063
# ('\nnum_reviews = ', u'13,063')
# 2143
# The Secret of Roan Inish
# 4.24
# 1957
# 17
# ('\nnum_reviews = ', u'17')
# 2144
# The Scorch Trials (The Maze Runner #2)
# 3.94
#
# 22,162
# ('\nnum_reviews = ', u'22,162')
# 2145
# Titus Andronicus
# 3.71
# 1589
# 967
# ('\nnum_reviews = ', u'967')
# 2146
# Shrek!
# 3.78
# 1990
# 234
# ('\nnum_reviews = ', u'234')
# 2147
# Me Before You (Me Before You #1)
# 4.28
# January 5th 2012
# 66,533
# ('\nnum_reviews = ', u'66,533')
# 2148
# The Glass Key
# 3.98
# 1931
# 350
# ('\nnum_reviews = ', u'350')
# 2149
# Gossip Girl (Gossip Girl #1)
# 3.5
# January 1st 2002
# 2,246
# ('\nnum_reviews = ', u'2,246')
# 2150
# Goodbye to Berlin
# 3.95
# 1939
# 375
# ('\nnum_reviews = ', u'375')
# 2151
# The Final Programme (Jerry Cornelius #1)
# 3.59
# March 1968
# 49
# ('\nnum_reviews = ', u'49')
# 2152
# The Man From Snowy River (Silver Brumby - Extended #17)
# 4.05
#
# 12
# ('\nnum_reviews = ', u'12')
# 2153
# Far and Away
# 3.94
# January 1st 1992
# 11
# ('\nnum_reviews = ', u'11')
# 2154
# Nights in Rodanthe
# 3.82
# January 1st 2002
# 3,902
# ('\nnum_reviews = ', u'3,902')
# 2155
# An Unsuitable Job For A Woman (Cordelia Gray #1)
# 3.84
# 1972
# 579
# ('\nnum_reviews = ', u'579')
# 2156
# Breakfast with Scot
# 3.63
# 1999
# 48
# ('\nnum_reviews = ', u'48')
# 2157
# The Surrogates (The Surrogates #1)
# 3.72
#
# 154
# ('\nnum_reviews = ', u'154')
# 2158
# The Wide Window (A Series of Unfortunate Events #3)
# 3.9
# 2000
# 2,837
# ('\nnum_reviews = ', u'2,837')
# 2159
# Carnosaur
# 3.19
#
# 8
# ('\nnum_reviews = ', u'8')
# 2160
# The Bonfire of the Vanities
# 3.8
# 1987
# 2,016
# ('\nnum_reviews = ', u'2,016')
# 2161
# The Birds and Other Stories
# 4.02
# January 1st 1952
# 296
# ('\nnum_reviews = ', u'296')
# 2162
# Ritual
# 3.16
# 1967
# 38
# ('\nnum_reviews = ', u'38')
# 2163
# All You Need Is Kill
# 4.05
# 2004
# 1,364
# ('\nnum_reviews = ', u'1,364')
# 2164
# Semi-Tough
# 3.87
# 1972
# 33
# ('\nnum_reviews = ', u'33')
# 2165
# Youth in Revolt (Youth in Revolt #1)
# 4.02
# August 1st 1993
# 837
# ('\nnum_reviews = ', u'837')
# 2166
# Desert of the Heart
# 3.87
# 1964
# 74
# ('\nnum_reviews = ', u'74')
# 2167
# The Wings of the Dove
# 3.8
# 1901
# 428
# ('\nnum_reviews = ', u'428')
# 2168
# Fantômas (Fantômas #1)
# 3.66
# January 1st 1911
# 115
# ('\nnum_reviews = ', u'115')
# 2169
# Monkey Shines
# 3.45
# 1983
# 12
# ('\nnum_reviews = ', u'12')
# 2170
# A Dark and Splendid Passion
# 3.82
# 1941
# 4
# ('\nnum_reviews = ', u'4')
# 2171
# The Sailor Who Fell from Grace with the Sea
# 3.89
# 1963
# 682
# ('\nnum_reviews = ', u'682')
# 2172
# Die Asche meiner Mutter: irische Erinnerungen (Frank McCourt #1)
# 4.06
# 1996
# 9,367
# ('\nnum_reviews = ', u'9,367')
# 2173
# The Loved One
# 3.79
# 1948
# 666
# ('\nnum_reviews = ', u'666')
# 2174
# The 39 Steps (Richard Hannay #1)
# 3.6
# August 1915
# 1,550
# ('\nnum_reviews = ', u'1,550')
# 2175
# A jangada de pedra
# 3.8
# 1986
# 313
# ('\nnum_reviews = ', u'313')
# 2176
# Dr. Mabuse
# 3.12
# 1921
# 6
# ('\nnum_reviews = ', u'6')
# 2177
# Starter for Ten
# 3.58
# 2003
# 1,041
# ('\nnum_reviews = ', u'1,041')
# 2178
# The House of Dr. Edwardes
# 3.32
# 1927
# 24
# ('\nnum_reviews = ', u'24')
# 2179
# The Five People You Meet in Heaven
# 3.9
# 2003
# 15,913
# ('\nnum_reviews = ', u'15,913')
# 2180
# Glengarry Glen Ross
# 3.94
# January 1st 1983
# 286
# ('\nnum_reviews = ', u'286')
# 2181
# Need for Speed
# 4.43
# February 4th 2014
# 16
# ('\nnum_reviews = ', u'16')
# 2182
# Allegiant (Divergent #3)
# 3.64
#
# 61,339
# ('\nnum_reviews = ', u'61,339')
# 2183
# Metropolis: New Revised Edition
# 3.63
# 1926
# 76
# ('\nnum_reviews = ', u'76')
# 2184
# Poor SAP
# 0.0
#
# 0
# ('\nnum_reviews = ', u'0')
# 2185
# Life With Mother Superior
# 4.06
# 1962
# 23
# ('\nnum_reviews = ', u'23')
# 2186
# Paprika
# 3.27
# 1993
# 229
# ('\nnum_reviews = ', u'229')
# 2187
# Pather panchali: Song of the road (অপুর পাঁচালী #1)
# 4.52
# 1929
# 115
# ('\nnum_reviews = ', u'115')
# 2188
# The Son of Neptune (The Heroes of Olympus #2)
# 4.45
#
# 11,435
# ('\nnum_reviews = ', u'11,435')
# 2189
# Born on the Fourth of July
# 3.82
# 1976
# 135
# ('\nnum_reviews = ', u'135')
# 2190
# Gregory's Girl
# 3.43
# February 1981
# 0
# ('\nnum_reviews = ', u'0')
# 2191
# Sin City, Vol. 1: The Hard Goodbye (Sin City #1)
# 4.15
# June 1992
# 734
# ('\nnum_reviews = ', u'734')
# 2192
# The Palace Thief
# 3.88
# January 1st 1994
# 132
# ('\nnum_reviews = ', u'132')
# 2193
# The King's Speech: How One Man Saved the British Monarchy
# 3.75
# November 30th 2010
# 803
# ('\nnum_reviews = ', u'803')
# 2194
# The Heart is a Lonely Hunter
# 3.96
# June 28th 1940
# 4,488
# ('\nnum_reviews = ', u'4,488')
# 2195
# Wicked: The Life and Times of the Wicked Witch of the West (The Wicked Years #1)
# 3.51
# 1995
# 22,493
# ('\nnum_reviews = ', u'22,493')
# 2196
# 58 Minutes (Die Hard #2)
# 3.53
# December 31st 1987
# 9
# ('\nnum_reviews = ', u'9')
# 2197
# Nemesis (Miss Marple #12)
# 3.84
#
# 663
# ('\nnum_reviews = ', u'663')
# 2198
# Portrait of Jennie
# 4.03
# 1940
# 112
# ('\nnum_reviews = ', u'112')
# 2199
# Attack on Titan, Volume 1 (Attack on Titan #1)
# 4.43
# March 17th 2010
# 1,374
# ('\nnum_reviews = ', u'1,374')
# 2200
# The Conformist
# 3.96
# 1951
# 78
# ('\nnum_reviews = ', u'78')
# 2201
# Skellig (Skellig #1)
# 3.76
# 1998
# 1,671
# ('\nnum_reviews = ', u'1,671')
# 2202
# The Leopard
# 3.98
# 1958
# 941
# ('\nnum_reviews = ', u'941')
# 2203
# The Day After Tomorrow
# 3.86
# January 1st 2004
# 40
# ('\nnum_reviews = ', u'40')
# 2204
# Paths of Glory
# 4.18
# 1935
# 38
# ('\nnum_reviews = ', u'38')
# 2205
# Endless Love
# 3.5
# 1979
# 379
# ('\nnum_reviews = ', u'379')
# 2206
# The Horseman on the Roof
# 3.91
# 1951
# 51
# ('\nnum_reviews = ', u'51')
# 2207
# Mia Goes Fourth (The Princess Diaries #4)
# 3.65
#
# 783
# ('\nnum_reviews = ', u'783')
# 2208
# Black Narcissus
# 3.86
# 1939
# 101
# ('\nnum_reviews = ', u'101')
# 2209
# The Fallen and Leviathan (The Fallen #1)
# 3.74
# January 1st 2010
# 857
# ('\nnum_reviews = ', u'857')
# 2210
# Meet Felicity: An American Girl (American Girls: Felicity #1)
# 3.86
# September 1st 1991
# 197
# ('\nnum_reviews = ', u'197')
# 2211
# The Shack
# 3.71
# May 1st 2007
# 26,354
# ('\nnum_reviews = ', u'26,354')
# 2212
# Meet Kit: An American Girl 1934 (American Girls: Kit #1)
# 3.94
# June 1st 2000
# 192
# ('\nnum_reviews = ', u'192')
# 2213
# Meet Samantha: An American Girl (American Girls: Samantha #1)
# 3.94
# January 1st 1986
# 248
# ('\nnum_reviews = ', u'248')
# 2214
# Prime Suspect (Prime Suspect #1)
# 3.82
# 1991
# 142
# ('\nnum_reviews = ', u'142')
# 2215
# Bridget Jones: The Edge of Reason (Bridget Jones #2)
# 3.51
# 1999
# 2,115
# ('\nnum_reviews = ', u'2,115')
# 2216
# Les Feluettes, ou La répétition d'un drame romantique
# 3.91
#
# 7
# ('\nnum_reviews = ', u'7')
# 2217
# For Your Eyes Only (James Bond (Original Series) #8)
# 3.64
# January 1st 1960
# 352
# ('\nnum_reviews = ', u'352')
# 2218
# The Buccaneers
# 3.9
# 1938
# 307
# ('\nnum_reviews = ', u'307')
# 2219
# Tuck Everlasting
# 3.85
# 1975
# 6,674
# ('\nnum_reviews = ', u'6,674')
# 2220
# Thunderball (James Bond (Original Series) #9)
# 3.78
# January 1st 1961
# 439
# ('\nnum_reviews = ', u'439')
# 2221
# Outside Over There
# 3.93
# 1981
# 312
# ('\nnum_reviews = ', u'312')
# 2222
# Sagwa, the Chinese Siamese Cat
# 3.98
# 1994
# 44
# ('\nnum_reviews = ', u'44')
# 2223
# On Her Majesty's Secret Service (James Bond (Original Series) #11)
# 3.93
# 1963
# 462
# ('\nnum_reviews = ', u'462')
# 2224
# The King's Damosel (The Three Damosels #2)
# 3.54
# 1975
# 22
# ('\nnum_reviews = ', u'22')
# 2225
# You Only Live Twice (James Bond (Original Series) #12)
# 3.75
# January 1st 1964
# 395
# ('\nnum_reviews = ', u'395')
# 2226
# Double Indemnity
# 4.12
# 1936
# 718
# ('\nnum_reviews = ', u'718')
# 2227
# Jane and the Dragon (Jane and the Dragon)
# 4.13
# January 1st 1988
# 27
# ('\nnum_reviews = ', u'27')
# 2228
# The Man With the Golden Gun (James Bond (Original Series) #13)
# 3.53
# January 1st 1965
# 337
# ('\nnum_reviews = ', u'337')
# 2229
# Perrault's Fairy Tales
# 4.2
# 1697
# 101
# ('\nnum_reviews = ', u'101')
# 2230
# Octopussy & the Living Daylights (James Bond (Original Series) #14)
# 3.53
# January 1st 1966
# 226
# ('\nnum_reviews = ', u'226')
# 2231
# Waltz With Bashir: A Lebanon War Story
# 3.88
# 2008
# 149
# ('\nnum_reviews = ', u'149')
# 2232
# Drugstore Cowboy
# 3.84
# 1990
# 23
# ('\nnum_reviews = ', u'23')
# 2233
# Solaris
# 3.97
# 1961
# 2,006
# ('\nnum_reviews = ', u'2,006')
# 2234
# The Journey (Guardians of Ga'Hoole #2)
# 3.99
# July 31st 2003
# 383
# ('\nnum_reviews = ', u'383')
# 2235
# The Rescue (Guardians of Ga'Hoole #3)
# 4.07
# December 1st 2003
# 265
# ('\nnum_reviews = ', u'265')
# Empty DataFrame
# Columns: []
# Index: []
